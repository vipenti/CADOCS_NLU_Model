# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_xlsx = '/content/drive/Shareddrives/CADOCS_Transformers/survey/survey_preprocessed.xlsx'

df = pd.read_excel(file_xlsx)

df['intent'] = ''

intent_values = ['get_smells'] * 57 + ['get_smells_date'] * 57 + ['report'] * 57 + ['info'] * (228 - 57 - 57 - 57)

df_merged = pd.DataFrame({
    'request': df.iloc[:, 0].values.tolist() + df.iloc[:, 1].values.tolist()
                     + df.iloc[:, 2].values.tolist() + df.iloc[:, 3].values.tolist(),
    'intent': intent_values
})

file_csv = '/content/drive/Shareddrives/CADOCS_Transformers/survey/survey.csv'

df_merged.to_csv(file_csv, index=False)
