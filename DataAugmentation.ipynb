# %% [markdown]
# **English Dataset Augmentation**
#
# In this file, we will increase the number of entries of the english dataset used by CADOCS using various functions provided by the NLPAug and TextAttack libraries.

# %% [markdown]
# First, we install the requested libraries.

# %%
# !pip install -q transformers datasets
# !pip install nlpaug
# !pip install sacremoses
# !pip install textattack
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nlpaug in /usr/local/lib/python3.10/dist-packages (1.1.11)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (1.22.4)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (1.5.3)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (2.27.1)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (3.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (4.11.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->nlpaug) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->nlpaug) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (2.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (1.7.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.10/dist-packages (0.0.53)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses) (2022.10.31)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sacremoses) (4.65.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textattack in /usr/local/lib/python3.10/dist-packages (0.3.8)
# Requirement already satisfied: bert-score>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from textattack) (0.3.13)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from textattack) (0.6.2)
# Requirement already satisfied: flair in /usr/local/lib/python3.10/dist-packages (from textattack) (0.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from textattack) (3.12.0)
# Requirement already satisfied: language-tool-python in /usr/local/lib/python3.10/dist-packages (from textattack) (2.7.1)
# Requirement already satisfied: lemminflect in /usr/local/lib/python3.10/dist-packages (from textattack) (0.2.3)
# Requirement already satisfied: lru-dict in /usr/local/lib/python3.10/dist-packages (from textattack) (1.2.0)
# Requirement already satisfied: datasets==2.4.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (2.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from textattack) (3.8.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (1.22.4)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from textattack) (1.5.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from textattack) (1.10.1)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (2.0.1+cu118)
# Requirement already satisfied: transformers>=4.21.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (4.29.2)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.10/dist-packages (from textattack) (3.1.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from textattack) (4.65.0)
# Requirement already satisfied: word2number in /usr/local/lib/python3.10/dist-packages (from textattack) (1.1)
# Requirement already satisfied: num2words in /usr/local/lib/python3.10/dist-packages (from textattack) (0.5.12)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from textattack) (9.1.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from textattack) (1.7.1)
# Requirement already satisfied: pinyin==0.4.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (0.4.0)
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from textattack) (0.42.1)
# Requirement already satisfied: OpenHowNet in /usr/local/lib/python3.10/dist-packages (from textattack) (2.0)
# Requirement already satisfied: pycld2 in /usr/local/lib/python3.10/dist-packages (from textattack) (0.41)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.10/dist-packages (from textattack) (8.0.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (9.0.0)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (0.3.5.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (2.27.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (0.70.13)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (0.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (23.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.4.0->textattack) (0.18.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score>=0.3.5->textattack) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->textattack) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->textattack) (2022.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.8,>=1.7.0->textattack) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.8,>=1.7.0->textattack) (16.0.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.21.0->textattack) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.21.0->textattack) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.21.0->textattack) (0.13.3)
# Requirement already satisfied: gensim>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (4.3.1)
# Requirement already satisfied: segtok>=1.5.7 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (1.5.11)
# Requirement already satisfied: mpld3==0.3 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (1.2.2)
# Requirement already satisfied: sqlitedict>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (2.1.0)
# Requirement already satisfied: deprecated>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (1.2.14)
# Requirement already satisfied: hyperopt>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.2.7)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (1.26.142)
# Requirement already satisfied: bpemb>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.3.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.8.10)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (1.0.9)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (4.9.2)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (6.1.1)
# Requirement already satisfied: janome in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.4.2)
# Requirement already satisfied: gdown==4.4.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (4.4.0)
# Requirement already satisfied: conllu>=4.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (4.5.2)
# Requirement already satisfied: wikipedia-api in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.5.8)
# Requirement already satisfied: pptree in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (3.1)
# Requirement already satisfied: pytorch-revgrad in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.2.0)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from flair->textattack) (0.2.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->flair->textattack) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->flair->textattack) (4.11.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->textattack) (1.2.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words->textattack) (0.6.2)
# Requirement already satisfied: anytree in /usr/local/lib/python3.10/dist-packages (from OpenHowNet->textattack) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from OpenHowNet->textattack) (67.7.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.2->flair->textattack) (0.1.99)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.4->flair->textattack) (1.14.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.4.0->textattack) (1.3.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=3.8.0->flair->textattack) (6.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack) (0.18.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack) (0.10.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.4.0->textattack) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.4.0->textattack) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.4.0->textattack) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->flair->textattack) (3.1.0)
# Requirement already satisfied: protobuf<=3.20.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.21.0->textattack) (3.20.2)
# Requirement already satisfied: botocore<1.30.0,>=1.29.142 in /usr/local/lib/python3.10/dist-packages (from boto3->flair->textattack) (1.29.142)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->flair->textattack) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3->flair->textattack) (0.6.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->flair->textattack) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.8,>=1.7.0->textattack) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.8,>=1.7.0->textattack) (1.3.0)
# Requirement already satisfied: accelerate>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.21.0->textattack) (0.19.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown==4.4.0->flair->textattack) (2.4.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.19.0->transformers>=4.21.0->textattack) (5.9.5)

# %% [markdown]
# Then, we import the dependencies

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertForSequenceClassification
from sklearn.model_selection import train_test_split
from textattack.transformations.sentence_transformations import BackTranslation
from textattack.transformations.word_insertions.word_insertion_masked_lm import WordInsertionMaskedLM
from textattack.transformations.word_insertions.word_insertion_random_synonym import WordInsertionRandomSynonym
from textattack.transformations.word_swaps.word_swap_masked_lm import WordSwapMaskedLM
from textattack.augmentation.recipes import EasyDataAugmenter, BackTranslationAugmenter
from textattack.transformations import WordSwapRandomCharacterDeletion, WordSwapQWERTY, CompositeTransformation
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.augmentation import Augmenter
import pandas as pd
import numpy as np
from sacremoses import MosesTokenizer, MosesDetokenizer

from tabulate import tabulate
from tqdm import trange
import random

import warnings
warnings.filterwarnings(action='once')

import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as nafc

from google.colab import drive

from six.moves import urllib
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()

# %% [markdown]
# We import the dataset and print it.

# %%
root="https://raw.githubusercontent.com/alfcan/CADOCS_NLU_Model/main/dataset.csv"

df = pd.read_csv(root, sep = ';', names=["request", "intent"])
label_mapping = {'get_smells': 0, 'get_smells_date': 1, 'report': 2, 'info': 3}
df['intent'] = df['intent'].map(label_mapping)

df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#                                              request  intent
# 0  Hello CADOCS, can you tell me which community ...       0
# 1  Hey CADOCS, tell which community smells are pr...       0
# 2   CADOCS can you tell which community smells ar...       0
# 3  I would like to know what are the community sm...       0
# 4  What are the community smells in the LINK proj...       0

# %% [markdown]
# We create lists of words that will not be modified by the augmentation functions

# %%
request = df.request.values
intent = df.intent.values

rows = []
stopwords_list=["community", "smells", "smell", "CADOCS","CAD", "LINK", "community smells", "repository"]
stopwordsContextual_list=["community", "smells", "smell", "community smells", "repository"]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# We create the new dataframe which will contain the new requests, inserting all the original requests in it.

# %%
dfAug = pd.DataFrame(columns=["request", "intent"])
dfAug = pd.concat([dfAug, df], ignore_index=True)
print(dfAug)
# Out:
#                                                request intent
# 0    Hello CADOCS, can you tell me which community ...      0
# 1    Hey CADOCS, tell which community smells are pr...      0
# 2     CADOCS can you tell which community smells ar...      0
# 3    I would like to know what are the community sm...      0
# 4    What are the community smells in the LINK proj...      0
# ..                                                 ...    ...
# 139  Hey CADOCS, what kind of community smells can ...      3
# 140  I wanna know more about community smells, it s...      3
# 141  hey CADOCS, can you show me some informations ...      3
# 142  Could you tell me more about community smells ...      3
# 143   CADOCS, What community smells have you detected?      3
#
# [144 rows x 2 columns]

# %% [markdown]
# A number of augmentation functions were evaluated, but most of them didn't produce approvable results. In particular, various kind of word augmentation functions provided by the NLPAug library were tried, such as nlpaug.augmenter.word.context_word_embs, nlpaug.augmenter.word.random, nlpaug.augmenter.word.synonym and WordInsertionRandomSynonym by TextAttack but the results produced by these functions were not considered acceptable for most of the sentences produced, which would then be discarded during requests selection.
#
#  The functions that generated the best requests are the following.
#
# WordSwapMaskedLM is a function of the TextAttack library which swaps words in sentences using a specified method and model, in this case 'bert-base-uncased'.
# After each augmentation function we remove the duplicates to perform an initial cleaning of the dataset.
#
# We chose to set the "min_confidence" parameter to 0.8, in order to obtain only the most realistic requests. For this reason, it was observed that most of the time the function is unable to produce new requests different form the original ones for each sentence in the original dataset, but only for some of them. The other parameters were set to achieve a good balance between quality and quantity of results and execution time.

# %%
transformationWordSwap = WordSwapMaskedLM(method='bae', masked_language_model='bert-base-uncased', tokenizer=None, max_length=512, max_candidates=3, min_confidence=0.8, batch_size=3)
constraintsWordSwap = [RepeatModification(), StopwordModification(stopwords=stopwords_list)]
wordSwapAugmenter = Augmenter(
    transformation=transformationWordSwap,
    constraints=constraintsWordSwap,
    transformations_per_example=1
)
wordSwapAugmenter.fast_augment = True
wordSwapAugmenter.high_yield = True

for index, row in df.iterrows():
  print("Original: ", row.request)
  augmentedRequests=wordSwapAugmenter.augment(row.request)
  print("Augmented: ",augmentedRequests)
  for i in augmentedRequests:
    if row.request.lower() != i.lower():
      rows.append({"request":i, "intent":row.intent})

dfAug = pd.concat([dfAug, pd.DataFrame(rows)], ignore_index=True)
dfAug = dfAug.loc[dfAug.astype(str).drop_duplicates().index]
print(dfAug)
rows = []
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Original:  Hello CADOCS, can you tell me which community smells are present in the repository LINK please?
# Augmented:  ['Hello CADOCS, can you tell me what community smells are present in the repository LINK please? ', 'Hello CADOCS, can you tell me which community smells are present in the repository LINK please? ']
# Original:  Hey CADOCS, tell which community smells are present in the repository LINK ?
# Augmented:  ['Hey CADOCS, tell which community smells are present in the repository LINK ?']
# Original:   CADOCS can you tell which community smells are present in the LINK ?
# Augmented:  [' CADOCS can you tell which community smells are present in the LINK ?']
# Original:  I would like to know what are the community smells in this LINK
# Augmented:  ['I would like to know what are the community smells in this LINK', 'i would like to know what are the community smells in this LINK']
# Original:  What are the community smells in the LINK project?"
# Augmented:  ['What are the community smells in the LINK project?"']
# Original:  Are there any community smell here, LINK?
# Augmented:  ['Are there any community smell here, LINK?', 'is there any community smell here, LINK?']
# Original:  Search community smells in the repository LINK
# Augmented:  ['Search community smells in the repository LINK', 'the community smells in the repository LINK']
# Original:  give me the community smells in LINK
# Augmented:  ['give me the community smells in LINK']
# Original:  CADOCS, can you tell me which community smells are present in the project LINK please?
# Augmented:  ['CADOCS, can you tell me what community smells are present in the project LINK please?', 'CADOCS, can you tell me which community smells are present in the project LINK please?']
# Original:  Hey! Community smells on LINK ?
# Augmented:  ['Hey! Community smells on LINK ?', 'Hey! what smells on LINK ?']
# Original:  Hey CADOCS could you tell me which community smells are in the LINK project?
# Augmented:  ['Hey CADOCS could you tell me what community smells are in the LINK project?', 'Hey CADOCS could you tell me which community smells are in the LINK project?']
# Original:  Hello, can you please tell me the community smells present in the LINK project?
# Augmented:  ['Hello, can you please tell me the community smells present in the LINK project?']
# Original:  Hello CASOCS, can you please tell me what are the community smells in the LINK project?
# Augmented:  ['Hello CASOCS, can you please tell me what are the community smells in the LINK project?']
# Original:  Can you please list me the community smells in the repository LINK?
# Augmented:  ['Can you please list all the community smells in the repository LINK?', 'Can you please list me the community smells in the repository LINK?']
# Original:  Hey, what are the community in this LINK repository?
# Augmented:  ['Hey, what are the community in this LINK repository?']
# Original:  CADOCS, show me the community smells present in repository LINK
# Augmented:  ['CADOCS, show me the community smells present in repository LINK', 'CADOCS, tell me the community smells present in repository LINK']
# Original:  I'd like to understand why contributors of LINK don't work well
# Augmented:  ["I'd like to know why contributors of LINK don't work well", "I'd like to understand why contributors of LINK don't work well", "I'd like to understand why contributors to LINK don't work well", "i like to understand why contributors of LINK don't work well"]
# Original:  CAD show me the community smells in this repo LINK
# Augmented:  ['CAD show me the community smells in this repo LINK']
# Original:  Hey Cadocs, which are the community smells in the LINK project?
# Augmented:  ['Hey Cadocs, which are the community smells in the LINK project?']
# Original:  CADOCS, which community smells are present here LINK?
# Augmented:  ['CADOCS, which community smells are present here LINK?']
# Original:  Hi CADOCS, find community smells in the LINK project
# Augmented:  ['Hi CADOCS, find community smells in the LINK project']
# Original:  Tell me all the community smells in this repo LINK
# Augmented:  ['Tell me all the community smells in this repo LINK']
# Original:  hello , what are the main community smells in the LINK project ?
# Augmented:  ['hello , what are the main community smells in the LINK project ?']
# Original:  Hey, can you scan this LINK for me?
# Augmented:  ['Hey, can you scan this LINK for me?']
# Original:  Hey CADOCS, which community smells are in the LINK project?
# Augmented:  ['Hey CADOCS, what community smells are in the LINK project?', 'Hey CADOCS, which community smells are in the LINK project?']
# Original:  CADOCS, search for smells in the LINK repo
# Augmented:  ['CADOCS, search for smells in the LINK repo']
# Original:  hi, what are the community smells in the LINK project
# Augmented:  ['hi, what are the community smells in the LINK project']
# Original:  Hey CADOCS, can you tell which community smells are present in the repository LINK please?
# Augmented:  ['Hey CADOCS, can you tell which community smells are present in the repository LINK please? ']
# Original:  Hi CADOCS, wich community are present in this repository LINK?
# Augmented:  ['Hi CADOCS, wich community are present in this repository LINK?']
# Original:  Hi, do you know what are the community smells in LINK repo?
# Augmented:  ['Hi, do you know what are the community smells in LINK repo?']
# Original:  hi, are there community smells in the LINK project??
# Augmented:  ['hi, are there community smells in the LINK project??']
# Original:  Hey CADOCS, what are the community smells in the repository LINK please?
# Augmented:  ['Hey CADOCS, what are the community smells in the repository LINK please? ']
# Original:  Hello CADOCS, can you tell which community smells are present in the repository LINK please?
# Augmented:  ['Hello CADOCS, can you tell which community smells are present in the repository LINK please?']
# Original:  Hey CADOCS, could you check if the repository at this LINK has community smells please?
# Augmented:  ['Hey CADOCS, could you check if the repository at this LINK has community smells please?']
# Original:  Hi CADOCS, could you check which community smells are present in the LINK project?
# Augmented:  ['Hi CADOCS, can you check which community smells are present in the LINK project?', 'Hi CADOCS, could you check if community smells are present in the LINK project?', 'Hi CADOCS, could you check which community smells are present in the LINK project?']
# Original:  What are the community smells in the LINK project?
# Augmented:  ['What are the community smells in the LINK project?']
# Original:  Hello CADOCS, you tell which community smells are present in the repository LINK after 03/21/2019?
# Augmented:  ['Hello CADOCS, you know which community smells are present in the repository LINK after 03/21/2019?', 'Hello CADOCS, you tell me community smells are present in the repository LINK after 03/21/2019?', 'Hello CADOCS, you tell which community smells are present in the repository LINK after 03/21/2019?']
# Original:  Hey CADOCS,  tell which community smells are present in the repository LINK after 03/23/2019
# Augmented:  ['Hey CADOCS,  tell which community smells are present in the repository LINK after 03/23/2019']
# Original:  CADOCS can you tell which community smells are present in the repository LINK after 01/16/2028?
# Augmented:  ['CADOCS can you tell which community smells are present in the repository LINK after 01/16/2028?']
# Original:  I would like to know what ate the community smells in this repo LINK starting from this date MM/DD/YYYY
# Augmented:  ['i would like to know what ate lier community smells in this repo LINK starting from this date MM/DD/YYYY', 'i would like to know what ate the community smells in this repo LINK starting from the date MM/DD/YYYY', 'i would like to know what ate the community smells in this repo LINK starting from this date MM/DD/YYYY', 'i would like to know who ate the community smells in this repo LINK starting from this date MM/DD/YYYY']
# Original:  Community smells in the LINK project from 27/04/2022?
# Augmented:  ['Community smells in the LINK project from 27/04/2022?']
# Original:  CADOCS can you check community smells in LINK starting from 18/04/2010?
# Augmented:  ['CADOCS can you check community smells in LINK starting from 18/04/2010?']
# Original:  Search community smells in the repository LINK after 12/19/2021
# Augmented:  ['Search community smells in the repository LINK after 12/19/2021']
# Original:  give me the community smells in LINK from on
# Augmented:  ['give me the community smells in LINK from on']
# Original:  CADOCS! Can you tell me which community smells are present in the repo LINK after the 03/30/2021?
# Augmented:  ['CADOCS! Can you tell me which community smells are present in the repo LINK after the 03/30/2021?', 'CADOCS! can you tell me which community smells are present in the repo LINK after the 03/30/2021?']
# Original:  Hey! Community smells on LINK starting from 01/01/2020?
# Augmented:  ['Hey! Community smells on LINK starting from 01/01/2020?']
# Original:  Hey CADOCS, can you tell which community smells are present in the repository LINK after 04/12/2016?
# Augmented:  ['Hey CADOCS, can you tell which community smells are present in the repository LINK after 04/12/2016?']
# Original:  Hello, can you please tell me the community smells present in the LINK project before 07/07/2021?
# Augmented:  ['Hello, can you please tell me the community smells present in the LINK project before 07/07/2021?']
# Original:  Hi CADOCS, can you please tell me what community smells are there in the LINK project starting from 06/09/2020?
# Augmented:  ['Hi CADOCS, can you please tell me what community smells are there in the LINK project starting from 06/09/2020?']
# Original:  List me the community smells in LINK starting from 03/03/2020
# Augmented:  ['List me the community smells in LINK starting from 03/03/2020', 'List of the community smells in LINK starting from 03/03/2020']
# Original:  CADOCS, can you tell me which community smells are present in this repository LINK after 05/01/2020?
# Augmented:  ['CADOCS, can you tell me which community smells are present in this repository LINK after 05/01/2020?']
# Original:  CADOCS, shoebke the community smells present in repository LINK after 12/19/2021
# Augmented:  ['CADOCS, shoebke the community smells present in repository LINK after 12/19/2021']
# Original:  Since June 23, 2020 the team in LINK have been acting weird. Why?
# Augmented:  ['Since June 23, 2020 the team in LINK has been acting weird. Why?', 'Since June 23, 2020 the team in LINK have been acting weird. Why?', 'since June 23, 2020 the team in LINK have been acting weird. Why?']
# Original:  CAD show me the community smells in this repo LINK starting from MM/DD/YYYY
# Augmented:  ['CAD show me the community smells in this repo LINK starting from MM/DD/YYYY']
# Original:  hey cadocs, which are the community smells in the LINK project from 12/19/2021?
# Augmented:  ['hey cadocs, which are the community smells in the LINK project from 12/19/2021?']
# Original:  CADOCS, which community smells are present here LINK after the 03/07/2022
# Augmented:  ['CADOCS, which community smells are present here LINK after the 03/07/2022', 'CADOCS, which community smells are present here LINK to the 03/07/2022']
# Original:  Hi CADOCS, are there any community smells in the LINK project starting from 11/11/2011?
# Augmented:  ['Hi CADOCS, are there any community smells in the LINK project starting from 11/11/2011?']
# Original:  Find all the community smells of this repo LINK from 05/05/2021
# Augmented:  ['Find all the community smells of this repo LINK from 05/05/2021']
# Original:  Hello CADOCS , which are the main community smells in the LINK pronject after 07/06/2020  ?
# Augmented:  ['Hello CADOCS , which are the main community smells in the LINK pronject after 07/06/2020  ?']
# Original:  Hi, what are the smells in this repository LINK starting from 05/06/2017?
# Augmented:  ['Hi, what are the smells in the repository LINK starting from 05/06/2017?', 'Hi, what are the smells in this repository LINK starting from 05/06/2017?']
# Original:  Hey CADOCS, which community smells are in the LINK project After 10/10/2020?
# Augmented:  ['Hey CADOCS, which community smells are in the LINK project After 10/10/2020?']
# Original:  CADOCS, search for smells in the LINK repo after 08/08/2018
# Augmented:  ['CADOCS, search for smells in the LINK repo after 08/08/2018']
# Original:  hi, what are the community smells in the LINK project starting from 12/19/2021??
# Augmented:  ['hi, what are the community smells in the LINK project starting from 12/19/2021??']
# Original:  Hi, what are the community smells in the LINK Project starting from 12/19/2021?
# Augmented:  ['Hi, what are the community smells in the LINK Project starting from 12/19/2021?']
# Original:  Hi CADOCS witch community smells are in this repository LINK from 05/06/2022
# Augmented:  ['Hi CADOCS witch community smells are in the repository LINK from 05/06/2022', 'Hi CADOCS witch community smells are in this repository LINK from 05/06/2022']
# Original:  Hi, i need all the community smells in LINK project after 31/12/2000
# Augmented:  ['Hi, i need all the community smells in LINK project after 31/12/2000']
# Original:   can you tell which community smells are present in the repository LINK defore 03/23/2020?
# Augmented:  [' can you tell which community smells are present in the repository LINK defore 03/23/2020?']
# Original:  Hey CADOCS, what are the community smells in the repository LINK project starting from 26/11/1999?
# Augmented:  ['Hey CADOCS, what are the community smells in the repository LINK project starting from 26/11/1999? ']
# Original:  Hello, what are the community smells in the LINK project date 12/12/20? Thanks in advance
# Augmented:  ['Hello, what are the community smells in the LINK project date 12/12/20? Thanks in advance']
# Original:  Hey CADOCS, could you check if the repository at this LINK has community smells, starting from 01/05/2020 please?
# Augmented:  ['Hey CADOCS, can you check if the repository at this LINK has community smells, starting from 01/05/2020 please?']
# Original:  hi CADOCS, could you check which smells of the community are present in the LINK project starting from 22/02/2020
# Augmented:  ['hi CADOCS, could you check which smells of the community are present in the LINK project starting from 22/02/2020']
# Original:  What are the community smells in the LINK project after 03/04/2020?
# Augmented:  ['What are the community smells in the LINK project after 03/04/2020?']
# Original:  Hello CADOCS, I need a report of your last execution
# Augmented:  ['Hello CADOCS, I need a report of your last execution']
# Original:  Hey CADOCS, give me a report of your last execution
# Augmented:  ['Hey CADOCS, give me a report of your last execution']
# Original:  CADOCS I need a report on your last execution, can you give it to me?
# Augmented:  ['CADOCS I need a report on your last execution, can you give it to me?']
# Original:  show a report about the last execution
# Augmented:  ['show a report about the last execution']
# Original:  I need a report of the last execution
# Augmented:  ['I need a report of the last execution']
# Original:  Illustrate to me the last execution's report
# Augmented:  ["Illustrate to me the last execution's report"]
# Original:  Give me last execution's report
# Augmented:  ["Give me last execution's report"]
# Original:  give me a report about the last execution
# Augmented:  ['give me a report about the last execution']
# Original:  CADOCS, can you generate to me a report of your last execution?
# Augmented:  ['CADOCS, can you generate for me a report of your last execution?', 'CADOCS, can you generate to me a report of your last execution?']
# Original:  Hey! Last execution?
# Augmented:  ['Hey! Last execution?']
# Original:  Hello, can you show me the information about your last execution, please?
# Augmented:  ['Hello, can you show me the information about your last execution, please?']
# Original:  Give me documentation about your last execution, please.
# Augmented:  ['Give me documentation about your last execution, please.']
# Original:  Please show me a report of your last execution.
# Augmented:  ['Please show me a report of your last execution.']
# Original:  Give me the report of your last execution
# Augmented:  ['Give me the report of your last execution']
# Original:  CADOCS, show me the info about your last execution
# Augmented:  ['CADOCS, show me the info about your last execution']
# Original:  CADOCS, show me the results of your last execution
# Augmented:  ['CADOCS, show me the results of your last execution']
# Original:  Could you make me a summary of what you did last time?
# Augmented:  ['Could you give me a summary of what you did last time?', 'Could you make me a summary of what you did last night?', 'Could you make me a summary of what you did last time?']
# Original:  CAD i want a report of last execution
# Augmented:  ['CAD i want a report of last execution']
# Original:  hey cadocs, show me about your last execution.
# Augmented:  ['hey cadocs, show me about your last execution.', 'hey cadocs, tell me about your last execution.']
# Original:  Show me information about your last execution
# Augmented:  ['Show me information about your last execution']
# Original:  Hi CADOCS, show me the report of your last execution
# Augmented:  ['Hi CADOCS, show me the report of the last execution', 'Hi CADOCS, show me the report of your last execution']
# Original:  Give me the report of the last execution
# Augmented:  ['Give me the report of the last execution']
# Original:  Show mr th last execution
# Augmented:  ['Show mr th last execution']
# Original:  Show me your last smell detection
# Augmented:  ['Show me your last smell detection']
# Original:  Hey CADOCS, report your last execution
# Augmented:  ['Hey CADOCS, report your last execution']
# Original:  CADOCS, report
# Augmented:  ['CADOCS, report']
# Original:  hello, show me information about your last execution.
# Augmented:  ['hello, show me information about your last execution.']
# Original:  I need a report if your last execution please
# Augmented:  ['I need a report if your last execution please', 'I need to report if your last execution please']
# Original:  Hi CADOCS give me the report of last execution
# Augmented:  ['Hi CADOCS give me the report of last execution']
# Original:  Hi, show me last execution report
# Augmented:  ['Hi, show me last execution report']
# Original:  I, tell me somethings  about your last execution
# Augmented:  ['I, tell me somethings  about your last execution']
# Original:  Hey CADOCS, I need a report of your last execution please
# Augmented:  ['Hey CADOCS, I need a report of your last execution please ']
# Original:  Hello, i need a report of your last task execution. Thanks in advance
# Augmented:  ['Hello, i need a report of your last task execution. Thanks in advance']
# Original:  hello CADOCS, please give me a report about your last execution!
# Augmented:  ['hello CADOCS, please give me a report about your last execution!']
# Original:  Could you give me a report on your last execution?
# Augmented:  ['Could you give me a report on your last execution?']
# Original:  Give me a report of your lady execution.
# Augmented:  ['Give me a report of your lady execution.']
# Original:  Hello CADOCS, what kind of community smells can you detect?
# Augmented:  ['Hello CADOCS, what kind of community smells can you detect?']
# Original:  Hey CADOCS, what kind of community smells can you detect?
# Augmented:  ['Hey CADOCS, what kind of community smells can you detect?']
# Original:  CADOCS i wanna know what kind of community smells can you detect?
# Augmented:  ['CADOCS i wanna know what kind of community smells can you detect?']
# Original:  I want to know more about the community smells detected
# Augmented:  ['I want to know more about the community smells detected', 'i want to know more about the community smells detected']
# Original:  What community smells can you detect?
# Augmented:  ['What community smells can you detect?', 'what community smells can you detect?']
# Original:  What can you detect about community smells?
# Augmented:  ['What can you detect about community smells?', 'what can you detect about community smells?']
# Original:  Give me community smells detected
# Augmented:  ['Give me community smells detected']
# Original:  what can you do?
# Augmented:  ['what can you do?']
# Original:  CADOS! Can you give me more information about the community smells that you can detect?
# Augmented:  ['CADOS! Can you give me more information about the community smells that i can detect?', 'CADOS! Can you give me more information about the community smells that you can detect?', 'CADOS! can you give me more information about the community smells that you can detect?']
# Original:  Hey! What are the community smells you detect?
# Augmented:  ['Hey! What are the community smells you detect?']
# Original:  Hey CADOCS, what kind of community smells can you detect?
# Augmented:  ['Hey CADOCS, what kind of community smells can you detect?']
# Original:  Hey CADOCS, in which field do you act?
# Augmented:  ['Hey CADOCS, in which field do you act? ']
# Original:  Hey CADOCS can you tell me more about the community smells you can detect?
# Augmented:  ['Hey CADOCS can you tell me more about the community smells you can detect?']
# Original:  Hi, what community smells are you able to find?
# Augmented:  ['Hi, what community smells are you able to find?']
# Original:  CADOCS what kind of community smells can you detect?
# Augmented:  ['CADOCS what kind of community smells can you detect?']
# Original:  CADOCS, what community smells can you detect?
# Augmented:  ['CADOCS, what community smells can you detect?']
# Original:  What are these community smells? How do I found more about community smells? What can you do for me?
# Augmented:  ['What are these community smells? How do I found more about community smells? What can you do for me?', 'What are these community smells? How do I found more about community smells? what can you do for me?', 'What are these community smells? How do I found out about community smells? What can you do for me?', 'What are these community smells? How have I found more about community smells? What can you do for me?', 'what are these community smells? How do I found more about community smells? What can you do for me?']
# Original:  CAD i want more information about community smells found
# Augmented:  ['CAD i want more information about community smells found']
# Original:  Hey cadocs, tell me about your community smells.
# Augmented:  ['Hey cadocs, tell me about your community smells.']
# Original:  CADOCS, what community smells can you detect?
# Augmented:  ['CADOCS, what community smells can you detect?']
# Original:  Hi CADOCS, which community smells are you able to detect?
# Augmented:  ['Hi CADOCS, what community smells are you able to detect?', 'Hi CADOCS, which community smells are you able to detect?']
# Original:  What type of community smells can you detect?
# Augmented:  ['What type of community smells can you detect?', 'what type of community smells can you detect?']
# Original:  Which kind of community smells can you detect ?
# Augmented:  ['Which kind of community smells can you detect ?', 'what kind of community smells can you detect ?']
# Original:  Tell me more about community smells
# Augmented:  ['Tell me more about community smells', 'tell me more about community smells']
# Original:  Hey CADOCS, tell me more about community smells
# Augmented:  ['Hey CADOCS, tell me more about community smells']
# Original:  CADOCS whay kind of smells can you detect?
# Augmented:  ['CADOCS what kind of smells can you detect?', 'CADOCS whay kind of smells can you detect?']
# Original:  hey CADOCS i wanna know more about community smells
# Augmented:  ['hey CADOCS i wanna know more about community smells']
# Original:  What kind of community smells can you detect?
# Augmented:  ['What kind of community smells can you detect? ', 'what kind of community smells can you detect? ']
# Original:  Hi CADOCS show me all kind of community you detect
# Augmented:  ['Hi CADOCS show me all kind of community you detect', 'Hi CADOCS show me what kind of community you detect']
# Original:  Hi, do you know what are community smells?
# Augmented:  ['Hi, do you know what are community smells?']
# Original:  hey CADOCS tell me somethings  about community smells
# Augmented:  ['hey CADOCS tell me somethings  about community smells']
# Original:  Hey CADOCS, what kind of community smells can you detect?
# Augmented:  ['Hey CADOCS, what kind of community smells can you detect? ']
# Original:  I wanna know more about community smells, it seems interesting
# Augmented:  ['I wanna know more about community smells, it seems interesting']
# Original:  hey CADOCS, can you show me some informations about community smells that you can detect?
# Augmented:  ['hey CADOCS, can you show me some informations about community smells that you can detect?']
# Original:  Could you tell me more about community smells and which ones you can detect?
# Augmented:  ['Could you tell me more about community smells and the ones you can detect?', 'Could you tell me more about community smells and which ones you can detect?', 'can you tell me more about community smells and which ones you can detect?']
# Original:  CADOCS, What community smells have you detected?
# Augmented:  ['CADOCS, What community smells have you detected?', 'CADOCS, what community smells have you detected?']
#                                                request intent
# 0    Hello CADOCS, can you tell me which community ...      0
# 1    Hey CADOCS, tell which community smells are pr...      0
# 2     CADOCS can you tell which community smells ar...      0
# 3    I would like to know what are the community sm...      0
# 4    What are the community smells in the LINK proj...      0
# ..                                                 ...    ...
# 179     what kind of community smells can you detect ?      3
# 180         CADOCS what kind of smells can you detect?      3
# 181  Hi CADOCS show me what kind of community you d...      3
# 182  Could you tell me more about community smells ...      3
# 183  can you tell me more about community smells an...      3
#
# [182 rows x 2 columns]

# %% [markdown]
#  WordInsertionMaskedLM class of TextAttack library generates new possible phrases inserting new words using a masked language model, which is also in this case "bert-base-uncased". We apply the transformations only on the original requests in order to introduce requests that are more meaningful and realistic. This is also the reason why the "min_confidence" parameter is also set to 0.8 in this case.
#
#  Like function WordSwapMaskedLM, this function also produces different phrases, with this parameter configuration, only for a subset of requests of the original dataset.

# %%
transformationWordInsertion = WordInsertionMaskedLM(masked_language_model='bert-base-uncased', tokenizer=None, max_length=512, max_candidates=3, min_confidence=0.8, batch_size=3)
constraintsWordInsertion = [RepeatModification(), StopwordModification(stopwords=stopwords_list)]
wordInsertionAugmenter = Augmenter(
    transformation=transformationWordInsertion,
    constraints=constraintsWordInsertion,
    transformations_per_example=1
)
wordInsertionAugmenter.fast_augment = True
wordInsertionAugmenter.high_yield = True

for index, row in df.iterrows():
  print("Original: ", row.request)
  augmentedRequests=wordInsertionAugmenter.augment(row.request)
  print("Augmented: ",augmentedRequests)
  for i in augmentedRequests:
    if row.request.lower() != i.lower():
      rows.append({"request":i, "intent":row.intent})

dfAug = pd.concat([dfAug, pd.DataFrame(rows)], ignore_index=True)
dfAug = dfAug.loc[dfAug.astype(str).drop_duplicates().index]
print(dfAug)
rows = []
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Original:  Hello CADOCS, can you tell me which community smells are present in the repository LINK please?
# Augmented:  ['Hello CADOCS, can you please tell me which community smells are present in the repository LINK please? ', 'Hello CADOCS, can you tell me which community smells are present in the repository LINK please? ', 'Hello CADOCS, can you tell me which community smells that are present in the repository LINK please? ']
# Original:  Hey CADOCS, tell which community smells are present in the repository LINK ?
# Augmented:  ['Hey CADOCS, tell which community smells are present in the repository LINK ?']
# Original:   CADOCS can you tell which community smells are present in the LINK ?
# Augmented:  [' CADOCS can help you tell which community smells are present in the LINK ?', ' CADOCS can you tell which community smells are present in the LINK ?', ' CADOCS can you tell which community smells that are present in the LINK ?']
# Original:  I would like to know what are the community smells in this LINK
# Augmented:  ['I would like to know what are all the community smells in this LINK', 'I would like to know what are the community smells in this LINK', 'I would like you to know what are the community smells in this LINK']
# Original:  What are the community smells in the LINK project?"
# Augmented:  ['What are the community smells in the LINK project?"', 'What are the community smells like in the LINK project?"']
# Original:  Are there any community smell here, LINK?
# Augmented:  ['Are there any community smell here, LINK?']
# Original:  Search community smells in the repository LINK
# Augmented:  ['Search community smells in the repository LINK']
# Original:  give me the community smells in LINK
# Augmented:  ['give me the community smells in LINK', 'give me what the community smells in LINK']
# Original:  CADOCS, can you tell me which community smells are present in the project LINK please?
# Augmented:  ['CADOCS, can help you tell me which community smells are present in the project LINK please?', 'CADOCS, can you please tell me which community smells are present in the project LINK please?', 'CADOCS, can you tell me which community smells are present in the project LINK please?', 'CADOCS, can you tell me which community smells that are present in the project LINK please?']
# Original:  Hey! Community smells on LINK ?
# Augmented:  ['Hey! Community smells on LINK ?']
# Original:  Hey CADOCS could you tell me which community smells are in the LINK project?
# Augmented:  ['Hey CADOCS could help you tell me which community smells are in the LINK project?', 'Hey CADOCS could you please tell me which community smells are in the LINK project?', 'Hey CADOCS could you tell me which community smells are in the LINK project?']
# Original:  Hello, can you please tell me the community smells present in the LINK project?
# Augmented:  ['Hello, can you please tell me the community smells present in the LINK project?']
# Original:  Hello CASOCS, can you please tell me what are the community smells in the LINK project?
# Augmented:  ['Hello CASOCS, can you please just tell me what are the community smells in the LINK project?', 'Hello CASOCS, can you please tell me what are the community smells in the LINK project?']
# Original:  Can you please list me the community smells in the repository LINK?
# Augmented:  ['Can you please list me the community smells in the repository LINK?']
# Original:  Hey, what are the community in this LINK repository?
# Augmented:  ['Hey, what are the community in this LINK repository?']
# Original:  CADOCS, show me the community smells present in repository LINK
# Augmented:  ['CADOCS, please show me the community smells present in repository LINK', 'CADOCS, show me the community smells present in repository LINK', 'CADOCS, show to me the community smells present in repository LINK']
# Original:  I'd like to understand why contributors of LINK don't work well
# Augmented:  ["I'd like to understand why contributors of LINK don't work well", "I'd like to understand why the contributors of LINK don't work well", "I'd like you to understand why contributors of LINK don't work well"]
# Original:  CAD show me the community smells in this repo LINK
# Augmented:  ['CAD show me how the community smells in this repo LINK', 'CAD show me the community smells in this repo LINK', 'CAD show me the community that smells in this repo LINK']
# Original:  Hey Cadocs, which are the community smells in the LINK project?
# Augmented:  ['Hey Cadocs, which are the community smells in the LINK project?']
# Original:  CADOCS, which community smells are present here LINK?
# Augmented:  ['CADOCS, which community smells are present here LINK?', 'CADOCS, which the community smells are present here LINK?']
# Original:  Hi CADOCS, find community smells in the LINK project
# Augmented:  ['Hi CADOCS, find community smells in the LINK project']
# Original:  Tell me all the community smells in this repo LINK
# Augmented:  ['Tell me all the community smells in this repo LINK', 'Tell me what all the community smells in this repo LINK']
# Original:  hello , what are the main community smells in the LINK project ?
# Augmented:  ['hello , what are the main community smells in the LINK project ?']
# Original:  Hey, can you scan this LINK for me?
# Augmented:  ['Hey, can you scan this LINK for me?']
# Original:  Hey CADOCS, which community smells are in the LINK project?
# Augmented:  ['Hey CADOCS, which community smells are in the LINK project?']
# Original:  CADOCS, search for smells in the LINK repo
# Augmented:  ['CADOCS, search for smells in the LINK repo']
# Original:  hi, what are the community smells in the LINK project
# Augmented:  ['hi, what are all the community smells in the LINK project', 'hi, what are the community smells in the LINK project']
# Original:  Hey CADOCS, can you tell which community smells are present in the repository LINK please?
# Augmented:  ['Hey CADOCS, can you tell which community smells are present in the repository LINK please? ', 'Hey CADOCS, can you tell which community smells that are present in the repository LINK please? ', 'Hey CADOCS, how can you tell which community smells are present in the repository LINK please? ']
# Original:  Hi CADOCS, wich community are present in this repository LINK?
# Augmented:  ['Hi CADOCS, wich community are present in this repository LINK?']
# Original:  Hi, do you know what are the community smells in LINK repo?
# Augmented:  ['Hi, do you know what are the community smells in LINK repo?', 'Hi, do you know what are the community smells like in LINK repo?']
# Original:  hi, are there community smells in the LINK project??
# Augmented:  ['hi, are there community smells in the LINK project??']
# Original:  Hey CADOCS, what are the community smells in the repository LINK please?
# Augmented:  ['Hey CADOCS, what are all the community smells in the repository LINK please? ', 'Hey CADOCS, what are the community smells in the repository LINK please? ']
# Original:  Hello CADOCS, can you tell which community smells are present in the repository LINK please?
# Augmented:  ['Hello CADOCS, can you tell me which community smells are present in the repository LINK please?', 'Hello CADOCS, can you tell which community smells are present in the repository LINK please?', 'Hello CADOCS, can you tell which community smells that are present in the repository LINK please?']
# Original:  Hey CADOCS, could you check if the repository at this LINK has community smells please?
# Augmented:  ['Hey CADOCS, could you check if the repository at this LINK has community smells please?']
# Original:  Hi CADOCS, could you check which community smells are present in the LINK project?
# Augmented:  ['Hi CADOCS, could you check out which community smells are present in the LINK project?', 'Hi CADOCS, could you check which community smells are present in the LINK project?', 'Hi CADOCS, could you check which community smells that are present in the LINK project?', 'Hi CADOCS, could you please check which community smells are present in the LINK project?']
# Original:  What are the community smells in the LINK project?
# Augmented:  ['What are the community smells in the LINK project?', 'What are the community smells like in the LINK project?']
# Original:  Hello CADOCS, you tell which community smells are present in the repository LINK after 03/21/2019?
# Augmented:  ['Hello CADOCS, can you tell which community smells are present in the repository LINK after 03/21/2019?', 'Hello CADOCS, you can tell which community smells are present in the repository LINK after 03/21/2019?', 'Hello CADOCS, you tell which community smells are present in the repository LINK after 03/21/2019?']
# Original:  Hey CADOCS,  tell which community smells are present in the repository LINK after 03/23/2019
# Augmented:  ['Hey CADOCS,  tell which community smells are present in the repository LINK after 03/23/2019']
# Original:  CADOCS can you tell which community smells are present in the repository LINK after 01/16/2028?
# Augmented:  ['CADOCS can help you tell which community smells are present in the repository LINK after 01/16/2028?', 'CADOCS can you tell which community smells are present in the repository LINK after 01/16/2028?', 'CADOCS can you tell which community smells that are present in the repository LINK after 01/16/2028?']
# Original:  I would like to know what ate the community smells in this repo LINK starting from this date MM/DD/YYYY
# Augmented:  ['I would like to know what ate the community smells in this repo LINK starting from this date MM/DD/YYYY', 'I would like to know what ate the community smells like in this repo LINK starting from this date MM/DD/YYYY', 'I would like you to know what ate the community smells in this repo LINK starting from this date MM/DD/YYYY']
# Original:  Community smells in the LINK project from 27/04/2022?
# Augmented:  ['Community smells in the LINK project from 27/04/2022?']
# Original:  CADOCS can you check community smells in LINK starting from 18/04/2010?
# Augmented:  ['CADOCS can help you check community smells in LINK starting from 18/04/2010?', 'CADOCS can you check community smells in LINK starting from 18/04/2010?']
# Original:  Search community smells in the repository LINK after 12/19/2021
# Augmented:  ['Search community smells in the repository LINK after 12/19/2021']
# Original:  give me the community smells in LINK from on
# Augmented:  ['give me the community smells in LINK from on', 'give me what the community smells in LINK from on']
# Original:  CADOCS! Can you tell me which community smells are present in the repo LINK after the 03/30/2021?
# Augmented:  ['CADOCS! Can you please tell me which community smells are present in the repo LINK after the 03/30/2021?', 'CADOCS! Can you tell me which community smells are present in the repo LINK after the 03/30/2021?', 'CADOCS! Can you tell me which community smells that are present in the repo LINK after the 03/30/2021?']
# Original:  Hey! Community smells on LINK starting from 01/01/2020?
# Augmented:  ['Hey! Community smells on LINK starting from 01/01/2020?']
# Original:  Hey CADOCS, can you tell which community smells are present in the repository LINK after 04/12/2016?
# Augmented:  ['Hey CADOCS, can you tell which community smells are present in the repository LINK after 04/12/2016?', 'Hey CADOCS, can you tell which community smells that are present in the repository LINK after 04/12/2016?', 'Hey CADOCS, how can you tell which community smells are present in the repository LINK after 04/12/2016?']
# Original:  Hello, can you please tell me the community smells present in the LINK project before 07/07/2021?
# Augmented:  ['Hello, can you please tell me the community smells present in the LINK project before 07/07/2021?']
# Original:  Hi CADOCS, can you please tell me what community smells are there in the LINK project starting from 06/09/2020?
# Augmented:  ['Hi CADOCS, can you please tell me what community smells are there in the LINK project starting from 06/09/2020?']
# Original:  List me the community smells in LINK starting from 03/03/2020
# Augmented:  ['List me the community smells in LINK starting from 03/03/2020']
# Original:  CADOCS, can you tell me which community smells are present in this repository LINK after 05/01/2020?
# Augmented:  ['CADOCS, can help you tell me which community smells are present in this repository LINK after 05/01/2020?', 'CADOCS, can you please tell me which community smells are present in this repository LINK after 05/01/2020?', 'CADOCS, can you tell me which community smells are present in this repository LINK after 05/01/2020?', 'CADOCS, can you tell me which community smells that are present in this repository LINK after 05/01/2020?']
# Original:  CADOCS, shoebke the community smells present in repository LINK after 12/19/2021
# Augmented:  ['CADOCS, shoebke the community smells present in repository LINK after 12/19/2021']
# Original:  Since June 23, 2020 the team in LINK have been acting weird. Why?
# Augmented:  ['Since June 23, 2020 the team in LINK have been acting weird. Why?']
# Original:  CAD show me the community smells in this repo LINK starting from MM/DD/YYYY
# Augmented:  ['CAD show me the community smells in this repo LINK starting from MM/DD/YYYY']
# Original:  hey cadocs, which are the community smells in the LINK project from 12/19/2021?
# Augmented:  ['hey cadocs, which are the community smells in the LINK project from 12/19/2021?']
# Original:  CADOCS, which community smells are present here LINK after the 03/07/2022
# Augmented:  ['CADOCS, which community smells are present here LINK after the 03/07/2022']
# Original:  Hi CADOCS, are there any community smells in the LINK project starting from 11/11/2011?
# Augmented:  ['Hi CADOCS, are there any community smells in the LINK project starting from 11/11/2011?', 'Hi CADOCS, are there any community smells in the LINK project starting from the 11/11/2011?']
# Original:  Find all the community smells of this repo LINK from 05/05/2021
# Augmented:  ['Find all the community smells of this repo LINK from 05/05/2021', 'Find out all the community smells of this repo LINK from 05/05/2021']
# Original:  Hello CADOCS , which are the main community smells in the LINK pronject after 07/06/2020  ?
# Augmented:  ['Hello CADOCS , which are the main community smells in the LINK pronject after 07/06/2020  ?']
# Original:  Hi, what are the smells in this repository LINK starting from 05/06/2017?
# Augmented:  ['Hi, what are all the smells in this repository LINK starting from 05/06/2017?', 'Hi, what are the smells in this repository LINK starting from 05/06/2017?']
# Original:  Hey CADOCS, which community smells are in the LINK project After 10/10/2020?
# Augmented:  ['Hey CADOCS, which community smells are in the LINK project After 10/10/2020?']
# Original:  CADOCS, search for smells in the LINK repo after 08/08/2018
# Augmented:  ['CADOCS, search for smells in the LINK repo after 08/08/2018']
# Original:  hi, what are the community smells in the LINK project starting from 12/19/2021??
# Augmented:  ['hi, what are the community smells in the LINK project starting from 12/19/2021??']
# Original:  Hi, what are the community smells in the LINK Project starting from 12/19/2021?
# Augmented:  ['Hi, what are the community smells in the LINK Project starting from 12/19/2021?']
# Original:  Hi CADOCS witch community smells are in this repository LINK from 05/06/2022
# Augmented:  ['Hi CADOCS witch community smells are in this repository LINK from 05/06/2022']
# Original:  Hi, i need all the community smells in LINK project after 31/12/2000
# Augmented:  ['Hi, i need all of the community smells in LINK project after 31/12/2000', 'Hi, i need all the community smells in LINK project after 31/12/2000']
# Original:   can you tell which community smells are present in the repository LINK defore 03/23/2020?
# Augmented:  [' can you tell which community smells are present in the repository LINK defore 03/23/2020?', ' can you tell which community smells that are present in the repository LINK defore 03/23/2020?']
# Original:  Hey CADOCS, what are the community smells in the repository LINK project starting from 26/11/1999?
# Augmented:  ['Hey CADOCS, what are the community smells in the repository LINK project starting from 26/11/1999? ']
# Original:  Hello, what are the community smells in the LINK project date 12/12/20? Thanks in advance
# Augmented:  ['Hello, what are all the community smells in the LINK project date 12/12/20? Thanks in advance', 'Hello, what are the community smells in the LINK project date 12/12/20? Thanks in advance']
# Original:  Hey CADOCS, could you check if the repository at this LINK has community smells, starting from 01/05/2020 please?
# Augmented:  ['Hey CADOCS, could you check if the repository at this LINK has community smells, starting from 01/05/2020 please?']
# Original:  hi CADOCS, could you check which smells of the community are present in the LINK project starting from 22/02/2020
# Augmented:  ['hi CADOCS, could you check which smells of the community are present in the LINK project starting from 22/02/2020']
# Original:  What are the community smells in the LINK project after 03/04/2020?
# Augmented:  ['What are the community smells in the LINK project after 03/04/2020?']
# Original:  Hello CADOCS, I need a report of your last execution
# Augmented:  ['Hello CADOCS, I need a report of your last execution']
# Original:  Hey CADOCS, give me a report of your last execution
# Augmented:  ['Hey CADOCS, give me a report of your last execution']
# Original:  CADOCS I need a report on your last execution, can you give it to me?
# Augmented:  ['CADOCS I need a report on your last execution, can you give it to me?', 'CADOCS I need a report on your last execution, can you please give it to me?']
# Original:  show a report about the last execution
# Augmented:  ['show a report about the last execution']
# Original:  I need a report of the last execution
# Augmented:  ['I need a report of the last execution']
# Original:  Illustrate to me the last execution's report
# Augmented:  ["Illustrate to me the last execution's report"]
# Original:  Give me last execution's report
# Augmented:  ["Give me last execution's report"]
# Original:  give me a report about the last execution
# Augmented:  ['give me a report about the last execution']
# Original:  CADOCS, can you generate to me a report of your last execution?
# Augmented:  ['CADOCS, can you generate to me a report of your last execution?', 'CADOCS, can you please generate to me a report of your last execution?']
# Original:  Hey! Last execution?
# Augmented:  ['Hey! Last execution?']
# Original:  Hello, can you show me the information about your last execution, please?
# Augmented:  ['Hello, can you please show me the information about your last execution, please?', 'Hello, can you show me all the information about your last execution, please?', 'Hello, can you show me the information about your last execution, please?']
# Original:  Give me documentation about your last execution, please.
# Augmented:  ['Give me documentation about your last execution, please.']
# Original:  Please show me a report of your last execution.
# Augmented:  ['Please show me a report of your last execution.', 'Please show to me a report of your last execution.']
# Original:  Give me the report of your last execution
# Augmented:  ['Give me the report of your last execution', 'Give to me the report of your last execution']
# Original:  CADOCS, show me the info about your last execution
# Augmented:  ['CADOCS, please show me the info about your last execution', 'CADOCS, show me all the info about your last execution', 'CADOCS, show me the info about your last execution']
# Original:  CADOCS, show me the results of your last execution
# Augmented:  ['CADOCS, please show me the results of your last execution', 'CADOCS, show me all the results of your last execution', 'CADOCS, show me the results of your last execution', 'CADOCS, show to me the results of your last execution']
# Original:  Could you make me a summary of what you did last time?
# Augmented:  ['Could you make for me a summary of what you did last time?', 'Could you make me a summary of what you did last time?', 'Could you make me a summary of what you did the last time?', 'Could you please make me a summary of what you did last time?']
# Original:  CAD i want a report of last execution
# Augmented:  ['CAD i want a report of last execution']
# Original:  hey cadocs, show me about your last execution.
# Augmented:  ['hey cadocs, show me about your last execution.']
# Original:  Show me information about your last execution
# Augmented:  ['Show me information about your last execution']
# Original:  Hi CADOCS, show me the report of your last execution
# Augmented:  ['Hi CADOCS, please show me the report of your last execution', 'Hi CADOCS, show me the report of your last execution', 'Hi CADOCS, show to me the report of your last execution']
# Original:  Give me the report of the last execution
# Augmented:  ['Give me the report of the last execution', 'Give to me the report of the last execution']
# Original:  Show mr th last execution
# Augmented:  ['Show mr th last execution']
# Original:  Show me your last smell detection
# Augmented:  ['Show me your last smell detection']
# Original:  Hey CADOCS, report your last execution
# Augmented:  ['Hey CADOCS, report on your last execution', 'Hey CADOCS, report your last execution']
# Original:  CADOCS, report
# Augmented:  ['CADOCS, report']
# Original:  hello, show me information about your last execution.
# Augmented:  ['hello, please show me information about your last execution.', 'hello, show me information about your last execution.']
# Original:  I need a report if your last execution please
# Augmented:  ['I need a report if not your last execution please', 'I need a report if your last execution please']
# Original:  Hi CADOCS give me the report of last execution
# Augmented:  ['Hi CADOCS give me the report of last execution', 'Hi CADOCS give to me the report of last execution']
# Original:  Hi, show me last execution report
# Augmented:  ['Hi, show me last execution report']
# Original:  I, tell me somethings  about your last execution
# Augmented:  ['I, tell me somethings  about your last execution']
# Original:  Hey CADOCS, I need a report of your last execution please
# Augmented:  ['Hey CADOCS, I need a report of your last execution please ', 'Hey CADOCS, I need you a report of your last execution please ']
# Original:  Hello, i need a report of your last task execution. Thanks in advance
# Augmented:  ['Hello, i need a report of your last task execution. Thanks in advance', 'Hello, i need a report of your last task in execution. Thanks in advance', 'Hello, i need you a report of your last task execution. Thanks in advance']
# Original:  hello CADOCS, please give me a report about your last execution!
# Augmented:  ['hello CADOCS, please give me a report about your last execution!']
# Original:  Could you give me a report on your last execution?
# Augmented:  ['Could you give me a report on your last execution?', 'Could you please give me a report on your last execution?']
# Original:  Give me a report of your lady execution.
# Augmented:  ['Give me a report of your lady execution.']
# Original:  Hello CADOCS, what kind of community smells can you detect?
# Augmented:  ['Hello CADOCS, what kind of community smells can you detect?']
# Original:  Hey CADOCS, what kind of community smells can you detect?
# Augmented:  ['Hey CADOCS, what kind of community smells can you detect?']
# Original:  CADOCS i wanna know what kind of community smells can you detect?
# Augmented:  ['CADOCS i wanna know what kind of community smells can you detect?', 'CADOCS i wanna to know what kind of community smells can you detect?']
# Original:  I want to know more about the community smells detected
# Augmented:  ['I want to know more about how the community smells detected', 'I want to know more about the community smells detected', 'I want you to know more about the community smells detected']
# Original:  What community smells can you detect?
# Augmented:  ['What community smells can help you detect?', 'What community smells can you detect?']
# Original:  What can you detect about community smells?
# Augmented:  ['What can you detect about community smells?']
# Original:  Give me community smells detected
# Augmented:  ['Give me community smells detected']
# Original:  what can you do?
# Augmented:  ['what can you do?', 'what can you possibly do?']
# Original:  CADOS! Can you give me more information about the community smells that you can detect?
# Augmented:  ['CADOS! Can you give me more information about the community smells so that you can detect?', 'CADOS! Can you give me more information about the community smells that only you can detect?', 'CADOS! Can you give me more information about the community smells that you can detect?', 'CADOS! Can you please give me more information about the community smells that you can detect?']
# Original:  Hey! What are the community smells you detect?
# Augmented:  ['Hey! What are the community smells you can detect?', 'Hey! What are the community smells you detect?']
# Original:  Hey CADOCS, what kind of community smells can you detect?
# Augmented:  ['Hey CADOCS, what kind of community smells can you detect?']
# Original:  Hey CADOCS, in which field do you act?
# Augmented:  ['Hey CADOCS, in which field do you act? ']
# Original:  Hey CADOCS can you tell me more about the community smells you can detect?
# Augmented:  ['Hey CADOCS can help you tell me more about the community smells you can detect?', 'Hey CADOCS can you please tell me more about the community smells you can detect?', 'Hey CADOCS can you tell me more about the community smells you can detect?']
# Original:  Hi, what community smells are you able to find?
# Augmented:  ['Hi, what community smells are you able to find?']
# Original:  CADOCS what kind of community smells can you detect?
# Augmented:  ['CADOCS what kind of community smells can help you detect?', 'CADOCS what kind of community smells can you detect?']
# Original:  CADOCS, what community smells can you detect?
# Augmented:  ['CADOCS, what community smells can you detect?']
# Original:  What are these community smells? How do I found more about community smells? What can you do for me?
# Augmented:  ['What are all these community smells? How do I found more about community smells? What can you do for me?', 'What are these community smells? How do I found more about community smells? What can you do for me?', 'What are these community smells? How do I found more information about community smells? What can you do for me?', 'What are these community smells? How do I found out more about community smells? What can you do for me?', 'What are these community smells? and How do I found more about community smells? What can you do for me?']
# Original:  CAD i want more information about community smells found
# Augmented:  ['CAD i want more information about community smells found', 'CAD i want some more information about community smells found']
# Original:  Hey cadocs, tell me about your community smells.
# Augmented:  ['Hey cadocs, tell me about your community smells.']
# Original:  CADOCS, what community smells can you detect?
# Augmented:  ['CADOCS, what community smells can you detect?']
# Original:  Hi CADOCS, which community smells are you able to detect?
# Augmented:  ['Hi CADOCS, which community smells are you able to detect?']
# Original:  What type of community smells can you detect?
# Augmented:  ['What type of community smells can help you detect?', 'What type of community smells can you detect?']
# Original:  Which kind of community smells can you detect ?
# Augmented:  ['Which kind of community smells can help you detect ?', 'Which kind of community smells can you detect ?']
# Original:  Tell me more about community smells
# Augmented:  ['Tell me more about community smells', 'Tell me some more about community smells']
# Original:  Hey CADOCS, tell me more about community smells
# Augmented:  ['Hey CADOCS, tell me more about community smells']
# Original:  CADOCS whay kind of smells can you detect?
# Augmented:  ['CADOCS whay kind of smells can you detect?', 'CADOCS whay what kind of smells can you detect?']
# Original:  hey CADOCS i wanna know more about community smells
# Augmented:  ['hey CADOCS i wanna know more about community smells', 'hey CADOCS i wanna to know more about community smells']
# Original:  What kind of community smells can you detect?
# Augmented:  ['What kind of community smells can help you detect? ', 'What kind of community smells can you detect? ']
# Original:  Hi CADOCS show me all kind of community you detect
# Augmented:  ['Hi CADOCS show me all kind of community you detect']
# Original:  Hi, do you know what are community smells?
# Augmented:  ['Hi, do you know what are community smells?']
# Original:  hey CADOCS tell me somethings  about community smells
# Augmented:  ['hey CADOCS tell me somethings  about community smells']
# Original:  Hey CADOCS, what kind of community smells can you detect?
# Augmented:  ['Hey CADOCS, what kind of community smells can you detect? ']
# Original:  I wanna know more about community smells, it seems interesting
# Augmented:  ['I wanna know more about community smells, it seems interesting', 'I wanna to know more about community smells, it seems interesting']
# Original:  hey CADOCS, can you show me some informations about community smells that you can detect?
# Augmented:  ['hey CADOCS, can you please show me some informations about community smells that you can detect?', 'hey CADOCS, can you show me some informations about community smells so that you can detect?', 'hey CADOCS, can you show me some informations about community smells that only you can detect?', 'hey CADOCS, can you show me some informations about community smells that you can detect?']
# Original:  Could you tell me more about community smells and which ones you can detect?
# Augmented:  ['Could you please tell me more about community smells and which ones you can detect?', 'Could you tell me more about community smells and which ones you can detect?', 'Could you tell me some more about community smells and which ones you can detect?']
# Original:  CADOCS, What community smells have you detected?
# Augmented:  ['CADOCS, What community smells have you detected?']
#                                                request intent
# 0    Hello CADOCS, can you tell me which community ...      0
# 1    Hey CADOCS, tell which community smells are pr...      0
# 2     CADOCS can you tell which community smells ar...      0
# 3    I would like to know what are the community sm...      0
# 4    What are the community smells in the LINK proj...      0
# ..                                                 ...    ...
# 285  hey CADOCS, can you please show me some inform...      3
# 286  hey CADOCS, can you show me some informations ...      3
# 287  hey CADOCS, can you show me some informations ...      3
# 288  Could you please tell me more about community ...      3
# 289  Could you tell me some more about community sm...      3
#
# [290 rows x 2 columns]

# %% [markdown]
# SpellingAug, of the NLPAug library, creates realistic spelling errors for original requests, in order to make the model to be built more robust. We apply this function also to the new requests created by the WordInsertionMaskedLM function, in order to obtain more results. In the parameters of this function, we decided to set the "aug_min" and "aug_max" values to 1, aiming to limit the words to be modified at just one, in order to keep the requests more realistic.

# %%
spellingAugmenter = naw.SpellingAug(dict_path=None, name='Spelling_Aug', aug_min=1, aug_max=1, stopwords=["LINK", "MM/DD/YYYY"], tokenizer=None, reverse_tokenizer=None, include_reverse=True, stopwords_regex=None, verbose=0)

for index, row in dfAug.iterrows():
  print("Original: ", row.request)
  augmentedRequests=spellingAugmenter.augment(row.request)
  print("Augmented: ",augmentedRequests[0])
  rows.append({"request":augmentedRequests[0], "intent":row.intent})

dfAug = pd.concat([dfAug, pd.DataFrame(rows)], ignore_index=True)
dfAug = dfAug.loc[dfAug.astype(str).drop_duplicates().index]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Original:  Hello CADOCS, can you tell me which community smells are present in the repository LINK please?
# Augmented:  Hello CADOCS, can you tell me which community smells are present ne the repository LINK please?
# Original:  Hey CADOCS, tell which community smells are present in the repository LINK ?
# Augmented:  Hey CADOCS, tell which community smells are present in thel repository LINK?
# Original:   CADOCS can you tell which community smells are present in the LINK ?
# Augmented:  CADOCS can you tell which community smells are présent in the LINK?
# Original:  I would like to know what are the community smells in this LINK
# Augmented:  I would like to kmow what are the community smells in this LINK
# Original:  What are the community smells in the LINK project?"
# Augmented:  What is the community smells in the LINK project? "
# Original:  Are there any community smell here, LINK?
# Augmented:  Are there any community smell [[Hier, LINK?
# Original:  Search community smells in the repository LINK
# Augmented:  Search community smells in Athe repository LINK
# Original:  give me the community smells in LINK
# Augmented:  give me the community smells ein LINK
# Original:  CADOCS, can you tell me which community smells are present in the project LINK please?
# Augmented:  CADOCS, can you tell me which community smells are present in thel project LINK please?
# Original:  Hey! Community smells on LINK ?
# Augmented:  Hi! Community smells on LINK?
# Original:  Hey CADOCS could you tell me which community smells are in the LINK project?
# Augmented:  Hey CADOCS could you tell me which comunity smells are in the LINK project?
# Original:  Hello, can you please tell me the community smells present in the LINK project?
# Augmented:  Hello, cane you please tell me the community smells present in the LINK project?
# Original:  Hello CASOCS, can you please tell me what are the community smells in the LINK project?
# Augmented:  Hello CASOCS, can you please tell me what are that community smells in the LINK project?
# Original:  Can you please list me the community smells in the repository LINK?
# Augmented:  Can yow please list me the community smells in the repository LINK?
# Original:  Hey, what are the community in this LINK repository?
# Augmented:  Hey, what are the community oin this LINK repository?
# Original:  CADOCS, show me the community smells present in repository LINK
# Augmented:  CADOCS, schow me the community smells present in repository LINK
# Original:  I'd like to understand why contributors of LINK don't work well
# Augmented:  I ' the like to understand why contributors of LINK don ' t work well
# Original:  CAD show me the community smells in this repo LINK
# Augmented:  CAD show me the comunnity smells in this repo LINK
# Original:  Hey Cadocs, which are the community smells in the LINK project?
# Augmented:  Hey Cadocs, which are ttt community smells in the LINK project?
# Original:  CADOCS, which community smells are present here LINK?
# Augmented:  CADOCS, whice community smells are present here LINK?
# Original:  Hi CADOCS, find community smells in the LINK project
# Augmented:  Hi CADOCS, find comunnity smells in the LINK project
# Original:  Tell me all the community smells in this repo LINK
# Augmented:  Tell me all tht community smells in this repo LINK
# Original:  hello , what are the main community smells in the LINK project ?
# Augmented:  hello, what are the main community smells ind the LINK project?
# Original:  Hey, can you scan this LINK for me?
# Augmented:  Hey, can you scan yoll'll LINK for me?
# Original:  Hey CADOCS, which community smells are in the LINK project?
# Augmented:  Hey CADOCS, [[wich community smells are in the LINK project?
# Original:  CADOCS, search for smells in the LINK repo
# Augmented:  CADOCS, search [[por smells in the LINK repo
# Original:  hi, what are the community smells in the LINK project
# Augmented:  hi, what are the community smells in the LINK projet
# Original:  Hey CADOCS, can you tell which community smells are present in the repository LINK please?
# Augmented:  Hey CADOCS, can you tell which community smells are pressent in the repository LINK please?
# Original:  Hi CADOCS, wich community are present in this repository LINK?
# Augmented:  Mi CADOCS, wich community are present in this repository LINK?
# Original:  Hi, do you know what are the community smells in LINK repo?
# Augmented:  Hi, do you know what are the commmunity smells in LINK repo?
# Original:  hi, are there community smells in the LINK project??
# Augmented:  hi, are there community smells in the LINK Proyect??
# Original:  Hey CADOCS, what are the community smells in the repository LINK please?
# Augmented:  Hey CADOCS, what are the community smeels in the repository LINK please?
# Original:  Hello CADOCS, can you tell which community smells are present in the repository LINK please?
# Augmented:  Hello CADOCS, can you tell which community smels are present in the repository LINK please?
# Original:  Hey CADOCS, could you check if the repository at this LINK has community smells please?
# Augmented:  Hey CADOCS, could you check if the repository at this LINK hs community smells please?
# Original:  Hi CADOCS, could you check which community smells are present in the LINK project?
# Augmented:  Hi CADOCS, could you check which community smalls are present in the LINK project?
# Original:  What are the community smells in the LINK project?
# Augmented:  What's are the community smells in the LINK project?
# Original:  Hello CADOCS, you tell which community smells are present in the repository LINK after 03/21/2019?
# Augmented:  Hello CADOCS, you tell wihch community smells are present in the repository LINK after 03 / 21 / 2019?
# Original:  Hey CADOCS,  tell which community smells are present in the repository LINK after 03/23/2019
# Augmented:  Ehy CADOCS, tell which community smells are present in the repository LINK after 03 / 23 / 2019
# Original:  CADOCS can you tell which community smells are present in the repository LINK after 01/16/2028?
# Augmented:  CADOCS can you tell which community smells are present in 5the repository LINK after 01 / 16 / 2028?
# Original:  I would like to know what ate the community smells in this repo LINK starting from this date MM/DD/YYYY
# Augmented:  I would like to nkow what ate the community smells in this repo LINK starting from this date MM / DD / YYYY
# Original:  Community smells in the LINK project from 27/04/2022?
# Augmented:  Community smells in the LINK project from 27th / 04 / 2022?
# Original:  CADOCS can you check community smells in LINK starting from 18/04/2010?
# Augmented:  CADOCS can you chick community smells in LINK starting from 18 / 04 / 2010?
# Original:  Search community smells in the repository LINK after 12/19/2021
# Augmented:  Search commmunity smells in the repository LINK after 12 / 19 / 2021
# Original:  give me the community smells in LINK from on
# Augmented:  give me the commmunity smells in LINK from on
# Original:  CADOCS! Can you tell me which community smells are present in the repo LINK after the 03/30/2021?
# Augmented:  CADOCS! Can you tell me which community smells are prensent in the repo LINK after the 03 / 30 / 2021?
# Original:  Hey! Community smells on LINK starting from 01/01/2020?
# Augmented:  Hey! Community smells oon LINK starting from 01 / 01 / 2020?
# Original:  Hey CADOCS, can you tell which community smells are present in the repository LINK after 04/12/2016?
# Augmented:  Hey CADOCS, cah you tell which community smells are present in the repository LINK after 04 / 12 / 2016?
# Original:  Hello, can you please tell me the community smells present in the LINK project before 07/07/2021?
# Augmented:  Hello, can ypu please tell me the community smells present in the LINK project before 07 / 07 / 2021?
# Original:  Hi CADOCS, can you please tell me what community smells are there in the LINK project starting from 06/09/2020?
# Augmented:  Hi CADOCS, can you please tell me what community smells are Thare in the LINK project starting from 06 / 09 / 2020?
# Original:  List me the community smells in LINK starting from 03/03/2020
# Augmented:  List me the community smells in LINK starting frome 03 / 03 / 2020
# Original:  CADOCS, can you tell me which community smells are present in this repository LINK after 05/01/2020?
# Augmented:  CADOCS, can you tell me which community smeels are present in this repository LINK after 05 / 01 / 2020?
# Original:  CADOCS, shoebke the community smells present in repository LINK after 12/19/2021
# Augmented:  CADOCS, shoebke the comunity smells present in repository LINK after 12 / 19 / 2021
# Original:  Since June 23, 2020 the team in LINK have been acting weird. Why?
# Augmented:  Since June 23th, 2020 the team in LINK have been acting weird. Why?
# Original:  CAD show me the community smells in this repo LINK starting from MM/DD/YYYY
# Augmented:  CAD show me the communit smells in this repo LINK starting from MM / DD / YYYY
# Original:  hey cadocs, which are the community smells in the LINK project from 12/19/2021?
# Augmented:  hey cadocs, which are the community smells in the LINK project from 20 / 19 / 2021?
# Original:  CADOCS, which community smells are present here LINK after the 03/07/2022
# Augmented:  CADOCS, which community smells are present hear LINK after the 03 / 07 / 2022
# Original:  Hi CADOCS, are there any community smells in the LINK project starting from 11/11/2011?
# Augmented:  Hi CADOCS, are there any community smell's in the LINK project starting from 11 / 11 / 2011?
# Original:  Find all the community smells of this repo LINK from 05/05/2021
# Augmented:  Find all then community smells of this repo LINK from 05 / 05 / 2021
# Original:  Hello CADOCS , which are the main community smells in the LINK pronject after 07/06/2020  ?
# Augmented:  Hello CADOCS, which are the mine community smells in the LINK pronject after 07 / 06 / 2020?
# Original:  Hi, what are the smells in this repository LINK starting from 05/06/2017?
# Augmented:  Hiii, what are the smells in this repository LINK starting from 05 / 06 / 2017?
# Original:  Hey CADOCS, which community smells are in the LINK project After 10/10/2020?
# Augmented:  Hey CADOCS, which community smells are in their LINK project After 10 / 10 / 2020?
# Original:  CADOCS, search for smells in the LINK repo after 08/08/2018
# Augmented:  CADOCS, search for smells in the LINK repo aftery 08 / 08 / 2018
# Original:  hi, what are the community smells in the LINK project starting from 12/19/2021??
# Augmented:  hi, what are the community smeels in the LINK project starting from 12 / 19 / 2021??
# Original:  Hi, what are the community smells in the LINK Project starting from 12/19/2021?
# Augmented:  Hi, what are the community smells ing the LINK Project starting from 12 / 19 / 2021?
# Original:  Hi CADOCS witch community smells are in this repository LINK from 05/06/2022
# Augmented:  Hi CADOCS witch community smells are in thise repository LINK from 05 / 06 / 2022
# Original:  Hi, i need all the community smells in LINK project after 31/12/2000
# Augmented:  Hi, i need all the community smels in LINK project after 31 / 12 / 2000
# Original:   can you tell which community smells are present in the repository LINK defore 03/23/2020?
# Augmented:  can you tell which community smeels are present in the repository LINK defore 03 / 23 / 2020?
# Original:  Hey CADOCS, what are the community smells in the repository LINK project starting from 26/11/1999?
# Augmented:  Hey CADOCS, what are thar community smells in the repository LINK project starting from 26 / 11 / 1999?
# Original:  Hello, what are the community smells in the LINK project date 12/12/20? Thanks in advance
# Augmented:  Hello, what are They community smells in the LINK project date 12 / 12 / 20? Thanks in advance
# Original:  Hey CADOCS, could you check if the repository at this LINK has community smells, starting from 01/05/2020 please?
# Augmented:  Hey CADOCS, could you check if thay repository at this LINK has community smells, starting from 01 / 05 / 2020 please?
# Original:  hi CADOCS, could you check which smells of the community are present in the LINK project starting from 22/02/2020
# Augmented:  hi CADOCS, could you check which smeels of the community are present in the LINK project starting from 22 / 02 / 2020
# Original:  What are the community smells in the LINK project after 03/04/2020?
# Augmented:  What are the community smells ii the LINK project after 03 / 04 / 2020?
# Original:  Hello CADOCS, I need a report of your last execution
# Augmented:  Hello CADOCS, J need a report of your last execution
# Original:  Hey CADOCS, give me a report of your last execution
# Augmented:  Hey CADOCS, give me a report of oyur last execution
# Original:  CADOCS I need a report on your last execution, can you give it to me?
# Augmented:  CADOCS I need a report on your Iast execution, can you give it to me?
# Original:  show a report about the last execution
# Augmented:  show a report abort the last execution
# Original:  I need a report of the last execution
# Augmented:  I need a report of the laste execution
# Original:  Illustrate to me the last execution's report
# Augmented:  Illustrate to me the last execution ' s repot
# Original:  Give me last execution's report
# Augmented:  Gvie me last execution ' s report
# Original:  give me a report about the last execution
# Augmented:  give we a report about the last execution
# Original:  CADOCS, can you generate to me a report of your last execution?
# Augmented:  CADOCS, can you generate to me a report of yor last execution?
# Original:  Hey! Last execution?
# Augmented:  Hei! Last execution?
# Original:  Hello, can you show me the information about your last execution, please?
# Augmented:  Hello, can you show MY the information about your last execution, please?
# Original:  Give me documentation about your last execution, please.
# Augmented:  Give me documentation about your last execution, pls.
# Original:  Please show me a report of your last execution.
# Augmented:  Please shou me a report of your last execution.
# Original:  Give me the report of your last execution
# Augmented:  Give me thet report of your last execution
# Original:  CADOCS, show me the info about your last execution
# Augmented:  CADOCS, show me the infos about your last execution
# Original:  CADOCS, show me the results of your last execution
# Augmented:  CADOCS, show me the results of yr last execution
# Original:  Could you make me a summary of what you did last time?
# Augmented:  Could you make me a summary of what you did last timt?
# Original:  CAD i want a report of last execution
# Augmented:  CAD i want a rapor of last execution
# Original:  hey cadocs, show me about your last execution.
# Augmented:  hey cadocs, show me about your lastly execution.
# Original:  Show me information about your last execution
# Augmented:  Show my information about your last execution
# Original:  Hi CADOCS, show me the report of your last execution
# Augmented:  Hi CADOCS, showe me the report of your last execution
# Original:  Give me the report of the last execution
# Augmented:  Give me the raport of the last execution
# Original:  Show mr th last execution
# Augmented:  Show mr th lost execution
# Original:  Show me your last smell detection
# Augmented:  Show me your lastly smell detection
# Original:  Hey CADOCS, report your last execution
# Augmented:  He CADOCS, report your last execution
# Original:  CADOCS, report
# Augmented:  CADOCS, reporte
# Original:  hello, show me information about your last execution.
# Augmented:  hello, show me information about yoir last execution.
# Original:  I need a report if your last execution please
# Augmented:  I need a report if your endest execution please
# Original:  Hi CADOCS give me the report of last execution
# Augmented:  Hi CADOCS give I the report of last execution
# Original:  Hi, show me last execution report
# Augmented:  Hy!, show me last execution report
# Original:  I, tell me somethings  about your last execution
# Augmented:  I, tell me somethings about tour last execution
# Original:  Hey CADOCS, I need a report of your last execution please
# Augmented:  Hey CADOCS, I need a report of your last execution plese
# Original:  Hello, i need a report of your last task execution. Thanks in advance
# Augmented:  Hello, i need a report of your last task execution. Thanks ín advance
# Original:  hello CADOCS, please give me a report about your last execution!
# Augmented:  hello CADOCS, please give me a report aboth your last execution!
# Original:  Could you give me a report on your last execution?
# Augmented:  Could you give me a report on your lazy execution?
# Original:  Give me a report of your lady execution.
# Augmented:  Give my a report of your lady execution.
# Original:  Hello CADOCS, what kind of community smells can you detect?
# Augmented:  Hello CADOCS, what kind of community smells can tou detect?
# Original:  Hey CADOCS, what kind of community smells can you detect?
# Augmented:  Hey CADOCS, what kind of community smells can youe detect?
# Original:  CADOCS i wanna know what kind of community smells can you detect?
# Augmented:  CADOCS i wanna know what kind of commmunity smells can you detect?
# Original:  I want to know more about the community smells detected
# Augmented:  I want to know mores about the community smells detected
# Original:  What community smells can you detect?
# Augmented:  What commmunity smells can you detect?
# Original:  What can you detect about community smells?
# Augmented:  What can you detect abuot community smells?
# Original:  Give me community smells detected
# Augmented:  Give me community smells delected
# Original:  what can you do?
# Augmented:  what can youy do?
# Original:  CADOS! Can you give me more information about the community smells that you can detect?
# Augmented:  CADOS! Can you give me more infromation about the community smells that you can detect?
# Original:  Hey! What are the community smells you detect?
# Augmented:  Hey! What are athe community smells you detect?
# Original:  Hey CADOCS, in which field do you act?
# Augmented:  Hey CADOCS, in which field do you etc?
# Original:  Hey CADOCS can you tell me more about the community smells you can detect?
# Augmented:  Hey CADOCS can you tell MY more about the community smells you can detect?
# Original:  Hi, what community smells are you able to find?
# Augmented:  Hi, what community smels are you able to find?
# Original:  CADOCS what kind of community smells can you detect?
# Augmented:  CADOCS what kindness of community smells can you detect?
# Original:  CADOCS, what community smells can you detect?
# Augmented:  CADOCS, wath's community smells can you detect?
# Original:  What are these community smells? How do I found more about community smells? What can you do for me?
# Augmented:  What are these community smels? How do I found more about community smells? What can you do for me?
# Original:  CAD i want more information about community smells found
# Augmented:  CAD in want more information about community smells found
# Original:  Hey cadocs, tell me about your community smells.
# Augmented:  He cadocs, tell me about your community smells.
# Original:  Hi CADOCS, which community smells are you able to detect?
# Augmented:  Hi CADOCS, which community smells are you able ton detect?
# Original:  What type of community smells can you detect?
# Augmented:  What type of community smell's can you detect?
# Original:  Which kind of community smells can you detect ?
# Augmented:  Which kin of community smells can you detect?
# Original:  Tell me more about community smells
# Augmented:  Tell me more Abut community smells
# Original:  Hey CADOCS, tell me more about community smells
# Augmented:  Hey CADOCS, tell me more about communit smells
# Original:  CADOCS whay kind of smells can you detect?
# Augmented:  CADOCS whay kinf of smells can you detect?
# Original:  hey CADOCS i wanna know more about community smells
# Augmented:  hey CADOCS i wanna know more about community smels
# Original:  What kind of community smells can you detect?
# Augmented:  What kind of community smells cane you detect?
# Original:  Hi CADOCS show me all kind of community you detect
# Augmented:  Hi CADOCS show me all kind of comunity you detect
# Original:  Hi, do you know what are community smells?
# Augmented:  Hi, do you know want are community smells?
# Original:  hey CADOCS tell me somethings  about community smells
# Augmented:  hey CADOCS tel me somethings about community smells
# Original:  Hey CADOCS, what kind of community smells can you detect?
# Augmented:  Hey CADOCS, what kind of community smeels can you detect?
# Original:  I wanna know more about community smells, it seems interesting
# Augmented:  I wanna know more about community smells, I''t seems interesting
# Original:  hey CADOCS, can you show me some informations about community smells that you can detect?
# Augmented:  they CADOCS, can you show me some informations about community smells that you can detect?
# Original:  Could you tell me more about community smells and which ones you can detect?
# Augmented:  Could you tell me more about community smells and witch ones you can detect?
# Original:  CADOCS, What community smells have you detected?
# Augmented:  CADOCS, Wht community smells have you detected?
# Original:  Hello CADOCS, can you tell me what community smells are present in the repository LINK please?
# Augmented:  Hello CADOCS, can you tell me whah community smells are present in the repository LINK please?
# Original:  is there any community smell here, LINK?
# Augmented:  ske there any community smell here, LINK?
# Original:  the community smells in the repository LINK
# Augmented:  rhe community smells in the repository LINK
# Original:  CADOCS, can you tell me what community smells are present in the project LINK please?
# Augmented:  CADOCS, can you tell me what community smells 're present in the project LINK please?
# Original:  Hey! what smells on LINK ?
# Augmented:  Hey! what smels on LINK?
# Original:  Hey CADOCS could you tell me what community smells are in the LINK project?
# Augmented:  Hey CADOCS could you tell me what commmunity smells are in the LINK project?
# Original:  Can you please list all the community smells in the repository LINK?
# Augmented:  Kan you please list all the community smells in the repository LINK?
# Original:  CADOCS, tell me the community smells present in repository LINK
# Augmented:  CADOCS, tell me the community smells preasent in repository LINK
# Original:  I'd like to know why contributors of LINK don't work well
# Augmented:  I ' d like to khow why contributors of LINK don ' t work well
# Original:  I'd like to understand why contributors to LINK don't work well
# Augmented:  I ' d like to understand why contributors to LINK don ' th work well
# Original:  i like to understand why contributors of LINK don't work well
# Augmented:  i like to understand why contributors of LINK don ' t wortk well
# Original:  Hey CADOCS, what community smells are in the LINK project?
# Augmented:  Hey CADOCS, what communit smells are in the LINK project?
# Original:  Hi CADOCS, can you check which community smells are present in the LINK project?
# Augmented:  Hi CADOCS, can you check which community smells are present avout the LINK project?
# Original:  Hi CADOCS, could you check if community smells are present in the LINK project?
# Augmented:  Hi CADOCS, cuold you check if community smells are present in the LINK project?
# Original:  Hello CADOCS, you know which community smells are present in the repository LINK after 03/21/2019?
# Augmented:  Hello CADOCS, you know which community smells are present in the repository LINK after 03 / 21th / 2019?
# Original:  Hello CADOCS, you tell me community smells are present in the repository LINK after 03/21/2019?
# Augmented:  Hello CADOCS, you tell me community smells are present in the repository LINK afeter 03 / 21 / 2019?
# Original:  i would like to know what ate lier community smells in this repo LINK starting from this date MM/DD/YYYY
# Augmented:  i would like to know what ate lier community smells in this repo LINK starting from htis date MM / DD / YYYY
# Original:  i would like to know what ate the community smells in this repo LINK starting from the date MM/DD/YYYY
# Augmented:  i would like to know what ate the comunity smells in this repo LINK starting from the date MM / DD / YYYY
# Original:  i would like to know who ate the community smells in this repo LINK starting from this date MM/DD/YYYY
# Augmented:  in would like to know who ate the community smells in this repo LINK starting from this date MM / DD / YYYY
# Original:  List of the community smells in LINK starting from 03/03/2020
# Augmented:  List of the community smells in LINK starting FORM 03 / 03 / 2020
# Original:  Since June 23, 2020 the team in LINK has been acting weird. Why?
# Augmented:  Since June 23, 2020 the team in LINK hav been acting weird. Why?
# Original:  CADOCS, which community smells are present here LINK to the 03/07/2022
# Augmented:  CADOCS, which community smells are present here LINK to ght 03 / 07 / 2022
# Original:  Hi, what are the smells in the repository LINK starting from 05/06/2017?
# Augmented:  Hi, what are the smell's in the repository LINK starting from 05 / 06 / 2017?
# Original:  Hi CADOCS witch community smells are in the repository LINK from 05/06/2022
# Augmented:  Hi CADOCS witch community smells are in the repository LINK Frm 05 / 06 / 2022
# Original:  Hey CADOCS, can you check if the repository at this LINK has community smells, starting from 01/05/2020 please?
# Augmented:  Hey CADOCS, can you check if the repository at this LINK has communit smells, starting from 01 / 05 / 2020 please?
# Original:  CADOCS, can you generate for me a report of your last execution?
# Augmented:  CADOCS, can you generate for me ein report of your last execution?
# Original:  Could you give me a summary of what you did last time?
# Augmented:  Could you give me a summary of what you doin last time?
# Original:  Could you make me a summary of what you did last night?
# Augmented:  Could you make MY a summary of what you did last night?
# Original:  hey cadocs, tell me about your last execution.
# Augmented:  they cadocs, tell me about your last execution.
# Original:  Hi CADOCS, show me the report of the last execution
# Augmented:  Hi CADOCS, show I the report of the last execution
# Original:  I need to report if your last execution please
# Augmented:  I need to rapor if your last execution please
# Original:  CADOS! Can you give me more information about the community smells that i can detect?
# Augmented:  CADOS! Can you gived me more information about the community smells that i can detect?
# Original:  What are these community smells? How do I found out about community smells? What can you do for me?
# Augmented:  Wat are these community smells? How do I found out about community smells? What can you do for me?
# Original:  What are these community smells? How have I found more about community smells? What can you do for me?
# Augmented:  What are these community smells? How have I found more about comunnity smells? What can you do for me?
# Original:  Hi CADOCS, what community smells are you able to detect?
# Augmented:  Hi CADOCS, waht community smells are you able to detect?
# Original:  what kind of community smells can you detect ?
# Augmented:  what kind of community smells can oyu detect?
# Original:  CADOCS what kind of smells can you detect?
# Augmented:  CADOCS what kind of smell's can you detect?
# Original:  Hi CADOCS show me what kind of community you detect
# Augmented:  Hi CADOCS schow me what kind of community you detect
# Original:  Could you tell me more about community smells and the ones you can detect?
# Augmented:  Could you tell me more about community smells and the ones oyu can detect?
# Original:  can you tell me more about community smells and which ones you can detect?
# Augmented:  can oyu tell me more about community smells and which ones you can detect?
# Original:  Hello CADOCS, can you please tell me which community smells are present in the repository LINK please?
# Augmented:  Hello CADOCS, can you please tell mi which community smells are present in the repository LINK please?
# Original:  Hello CADOCS, can you tell me which community smells that are present in the repository LINK please?
# Augmented:  Hello CADOCS, can you tell me which commmunity smells that are present in the repository LINK please?
# Original:   CADOCS can help you tell which community smells are present in the LINK ?
# Augmented:  CADOCS can help you tell whic community smells are present in the LINK?
# Original:   CADOCS can you tell which community smells that are present in the LINK ?
# Augmented:  CADOCS cacn you tell which community smells that are present in the LINK?
# Original:  I would like to know what are all the community smells in this LINK
# Augmented:  I would like to know what are all thirty community smells in this LINK
# Original:  I would like you to know what are the community smells in this LINK
# Augmented:  I would like you to know what ar the community smells in this LINK
# Original:  What are the community smells like in the LINK project?"
# Augmented:  What are the community smells lake in the LINK project? "
# Original:  give me what the community smells in LINK
# Augmented:  give me what the community smeels in LINK
# Original:  CADOCS, can help you tell me which community smells are present in the project LINK please?
# Augmented:  CADOCS, can help you tell m which community smells are present in the project LINK please?
# Original:  CADOCS, can you please tell me which community smells are present in the project LINK please?
# Augmented:  CADOCS, can you please tell me whitch community smells are present in the project LINK please?
# Original:  CADOCS, can you tell me which community smells that are present in the project LINK please?
# Augmented:  CADOCS, can you tell me [[wich community smells that are present in the project LINK please?
# Original:  Hey CADOCS could help you tell me which community smells are in the LINK project?
# Augmented:  Hey CADOCS could help you tell me which comunnity smells are in the LINK project?
# Original:  Hey CADOCS could you please tell me which community smells are in the LINK project?
# Augmented:  Hey CADOCS could you please tell me which community smells are in tyhe LINK project?
# Original:  Hello CASOCS, can you please just tell me what are the community smells in the LINK project?
# Augmented:  Heiio CASOCS, can you please just tell me what are the community smells in the LINK project?
# Original:  CADOCS, please show me the community smells present in repository LINK
# Augmented:  CADOCS, please show me the community smells present into repository LINK
# Original:  CADOCS, show to me the community smells present in repository LINK
# Augmented:  CADOCS, show to me the community smalls present in repository LINK
# Original:  I'd like to understand why the contributors of LINK don't work well
# Augmented:  Me ' d like to understand why the contributors of LINK don ' t work well
# Original:  I'd like you to understand why contributors of LINK don't work well
# Augmented:  I ' d like you to understand why contributors of LINK don ' t york well
# Original:  CAD show me how the community smells in this repo LINK
# Augmented:  CAD show MY how the community smells in this repo LINK
# Original:  CAD show me the community that smells in this repo LINK
# Augmented:  CAD show me the community that smalls in this repo LINK
# Original:  CADOCS, which the community smells are present here LINK?
# Augmented:  CADOCS, which yhe community smells are present here LINK?
# Original:  Tell me what all the community smells in this repo LINK
# Augmented:  Teel me what all the community smells in this repo LINK
# Original:  hi, what are all the community smells in the LINK project
# Augmented:  hi, what are all the community smells in he LINK project
# Original:  Hey CADOCS, can you tell which community smells that are present in the repository LINK please?
# Augmented:  Hey CADOCS, can you tell which community smells that care present in the repository LINK please?
# Original:  Hey CADOCS, how can you tell which community smells are present in the repository LINK please?
# Augmented:  Hey CADOCS, how can you tell which community smells are presente in the repository LINK please?
# Original:  Hi, do you know what are the community smells like in LINK repo?
# Augmented:  Hi, do en know what are the community smells like in LINK repo?
# Original:  Hey CADOCS, what are all the community smells in the repository LINK please?
# Augmented:  Hey CADOCS, what are all tho community smells in the repository LINK please?
# Original:  Hello CADOCS, can you tell me which community smells are present in the repository LINK please?
# Augmented:  Hello CADOCS, can you tell me which community smells are present in d repository LINK please?
# Original:  Hello CADOCS, can you tell which community smells that are present in the repository LINK please?
# Augmented:  Hello CADOCS, can you tell [[wich community smells that are present in the repository LINK please?
# Original:  Hi CADOCS, could you check out which community smells are present in the LINK project?
# Augmented:  Hi CADOCS, could you check out which community smels are present in the LINK project?
# Original:  Hi CADOCS, could you check which community smells that are present in the LINK project?
# Augmented:  Hi CADOCS, could you cheque which community smells that are present in the LINK project?
# Original:  Hi CADOCS, could you please check which community smells are present in the LINK project?
# Augmented:  Hi CADOCS, coulkd you please check which community smells are present in the LINK project?
# Original:  What are the community smells like in the LINK project?
# Augmented:  Whate are the community smells like in the LINK project?
# Original:  Hello CADOCS, can you tell which community smells are present in the repository LINK after 03/21/2019?
# Augmented:  Hello CADOCS, can you tell which community smeels are present in the repository LINK after 03 / 21 / 2019?
# Original:  Hello CADOCS, you can tell which community smells are present in the repository LINK after 03/21/2019?
# Augmented:  Hello CADOCS, you can tell which community smell's are present in the repository LINK after 03 / 21 / 2019?
# Original:  CADOCS can help you tell which community smells are present in the repository LINK after 01/16/2028?
# Augmented:  CADOCS can happing you tell which community smells are present in the repository LINK after 01 / 16 / 2028?
# Original:  CADOCS can you tell which community smells that are present in the repository LINK after 01/16/2028?
# Augmented:  CADOCS can you tell which community smells that are present in the repository LINK ater 01 / 16 / 2028?
# Original:  I would like to know what ate the community smells like in this repo LINK starting from this date MM/DD/YYYY
# Augmented:  I would like to know what ate the community smells like in this repo LINK starting fro this date MM / DD / YYYY
# Original:  I would like you to know what ate the community smells in this repo LINK starting from this date MM/DD/YYYY
# Augmented:  I would like you to know what ate the community smells in this repo LINK starting frow this date MM / DD / YYYY
# Original:  CADOCS can help you check community smells in LINK starting from 18/04/2010?
# Augmented:  CADOCS can helo you check community smells in LINK starting from 18 / 04 / 2010?
# Original:  give me what the community smells in LINK from on
# Augmented:  give me what the community smells in LINK from 0n
# Original:  CADOCS! Can you please tell me which community smells are present in the repo LINK after the 03/30/2021?
# Augmented:  CADOCS! Can you please tell me which community smells are present I the repo LINK after the 03 / 30 / 2021?
# Original:  CADOCS! Can you tell me which community smells that are present in the repo LINK after the 03/30/2021?
# Augmented:  CADOCS! Can you tell me which community smells that rare present in the repo LINK after the 03 / 30 / 2021?
# Original:  Hey CADOCS, can you tell which community smells that are present in the repository LINK after 04/12/2016?
# Augmented:  Hey CADOCS, can your tell which community smells that are present in the repository LINK after 04 / 12 / 2016?
# Original:  Hey CADOCS, how can you tell which community smells are present in the repository LINK after 04/12/2016?
# Augmented:  Hey CADOCS, how can YOY tell which community smells are present in the repository LINK after 04 / 12 / 2016?
# Original:  CADOCS, can help you tell me which community smells are present in this repository LINK after 05/01/2020?
# Augmented:  CADOCS, can help you tell me which community smells are pressent in this repository LINK after 05 / 01 / 2020?
# Original:  CADOCS, can you please tell me which community smells are present in this repository LINK after 05/01/2020?
# Augmented:  CADOCS, can you please tell me which community smells are present in this repository LINK aftter 05 / 01 / 2020?
# Original:  CADOCS, can you tell me which community smells that are present in this repository LINK after 05/01/2020?
# Augmented:  CADOCS, can you tell me which community smells that are present in this repository LINK afeter 05 / 01 / 2020?
# Original:  Hi CADOCS, are there any community smells in the LINK project starting from the 11/11/2011?
# Augmented:  Hi CADOCS, are there any community smeels in the LINK project starting from the 11 / 11 / 2011?
# Original:  Find out all the community smells of this repo LINK from 05/05/2021
# Augmented:  Find out all the community smells of this repo LINK fro 05 / 05 / 2021
# Original:  Hi, what are all the smells in this repository LINK starting from 05/06/2017?
# Augmented:  Hi, what are all the smells ii this repository LINK starting from 05 / 06 / 2017?
# Original:  Hi, i need all of the community smells in LINK project after 31/12/2000
# Augmented:  Hi, i need all of the community smeels in LINK project after 31 / 12 / 2000
# Original:   can you tell which community smells that are present in the repository LINK defore 03/23/2020?
# Augmented:  can you tell which community smells thet are present in the repository LINK defore 03 / 23 / 2020?
# Original:  Hello, what are all the community smells in the LINK project date 12/12/20? Thanks in advance
# Augmented:  Hello, what are oll the community smells in the LINK project date 12 / 12 / 20? Thanks in advance
# Original:  CADOCS I need a report on your last execution, can you please give it to me?
# Augmented:  CADOCS I need are report on your last execution, can you please give it to me?
# Original:  CADOCS, can you please generate to me a report of your last execution?
# Augmented:  CADOCS, cat you please generate to me a report of your last execution?
# Original:  Hello, can you please show me the information about your last execution, please?
# Augmented:  Hello, can you please show me the informatons about your last execution, please?
# Original:  Hello, can you show me all the information about your last execution, please?
# Augmented:  Hello, can you show me all the informaton about your last execution, please?
# Original:  Please show to me a report of your last execution.
# Augmented:  Please show to me as report of your last execution.
# Original:  Give to me the report of your last execution
# Augmented:  Gvie to me the report of your last execution
# Original:  CADOCS, please show me the info about your last execution
# Augmented:  CADOCS, please show me the info about your lst execution
# Original:  CADOCS, show me all the info about your last execution
# Augmented:  CADOCS, show me all tle info about your last execution
# Original:  CADOCS, please show me the results of your last execution
# Augmented:  CADOCS, Pls show me the results of your last execution
# Original:  CADOCS, show me all the results of your last execution
# Augmented:  CADOCS, show me all the results of ou last execution
# Original:  CADOCS, show to me the results of your last execution
# Augmented:  CADOCS, show to me the results ow your last execution
# Original:  Could you make for me a summary of what you did last time?
# Augmented:  Could you make for mo a summary of what you did last time?
# Original:  Could you make me a summary of what you did the last time?
# Augmented:  Could you make m a summary of what you did the last time?
# Original:  Could you please make me a summary of what you did last time?
# Augmented:  Could you please make me a summary of what you Dad last time?
# Original:  Hi CADOCS, please show me the report of your last execution
# Augmented:  Hi CADOCS, please show be the report of your last execution
# Original:  Hi CADOCS, show to me the report of your last execution
# Augmented:  Hi CADOCS, show to me the report or your last execution
# Original:  Give to me the report of the last execution
# Augmented:  Give to me the repot of the last execution
# Original:  Hey CADOCS, report on your last execution
# Augmented:  Hey CADOCS, report oon your last execution
# Original:  hello, please show me information about your last execution.
# Augmented:  hello, please shows me information about your last execution.
# Original:  I need a report if not your last execution please
# Augmented:  0I need a report if not your last execution please
# Original:  Hi CADOCS give to me the report of last execution
# Augmented:  Hi CADOCS give to me ht report of last execution
# Original:  Hey CADOCS, I need you a report of your last execution please
# Augmented:  Hey CADOCS, ai need you a report of your last execution please
# Original:  Hello, i need a report of your last task in execution. Thanks in advance
# Augmented:  Hello, i need a report of yours last task in execution. Thanks in advance
# Original:  Hello, i need you a report of your last task execution. Thanks in advance
# Augmented:  Hello, i need you a report of your last task execution. tenkes in advance
# Original:  Could you please give me a report on your last execution?
# Augmented:  Could gou please give me a report on your last execution?
# Original:  CADOCS i wanna to know what kind of community smells can you detect?
# Augmented:  CADOCS i wanna tou know what kind of community smells can you detect?
# Original:  I want to know more about how the community smells detected
# Augmented:  I want to know more about how the community smeels detected
# Original:  I want you to know more about the community smells detected
# Augmented:  I want you to know more aboth the community smells detected
# Original:  What community smells can help you detect?
# Augmented:  What communit smells can help you detect?
# Original:  what can you possibly do?
# Augmented:  whhat can you possibly do?
# Original:  CADOS! Can you give me more information about the community smells so that you can detect?
# Augmented:  CADOS! Can you give me morw information about the community smells so that you can detect?
# Original:  CADOS! Can you give me more information about the community smells that only you can detect?
# Augmented:  CADOS! Can you give me more information about thez community smells that only you can detect?
# Original:  CADOS! Can you please give me more information about the community smells that you can detect?
# Augmented:  CADOS! Can you please give me more information about the comunnity smells that you can detect?
# Original:  Hey! What are the community smells you can detect?
# Augmented:  Hey! Waht are the community smells you can detect?
# Original:  Hey CADOCS can help you tell me more about the community smells you can detect?
# Augmented:  Hey CADOCS can help you tell me more about the community smeels you can detect?
# Original:  Hey CADOCS can you please tell me more about the community smells you can detect?
# Augmented:  Hey CADOCS cfn you please tell me more about the community smells you can detect?
# Original:  CADOCS what kind of community smells can help you detect?
# Augmented:  CADOCS what kind of community smells can help yours detect?
# Original:  What are all these community smells? How do I found more about community smells? What can you do for me?
# Augmented:  What are all these community smells? How do I found more about communit smells? What can you do for me?
# Original:  What are these community smells? How do I found more information about community smells? What can you do for me?
# Augmented:  What are these community smells? How do I found more information about community smell's? What can you do for me?
# Original:  What are these community smells? How do I found out more about community smells? What can you do for me?
# Augmented:  What are these community smells? How do I found out more about community smells? What can you DON for me?
# Original:  What are these community smells? and How do I found more about community smells? What can you do for me?
# Augmented:  What are these community smells? and How do I found more abourt community smells? What can you do for me?
# Original:  CAD i want some more information about community smells found
# Augmented:  CAD I’ve want some more information about community smells found
# Original:  What type of community smells can help you detect?
# Augmented:  What type of community smells can help your detect?
# Original:  Which kind of community smells can help you detect ?
# Augmented:  Which kind of comunnity smells can help you detect?
# Original:  Tell me some more about community smells
# Augmented:  Tell me somne more about community smells
# Original:  CADOCS whay what kind of smells can you detect?
# Augmented:  CADOCS whay what kind of smell's can you detect?
# Original:  hey CADOCS i wanna to know more about community smells
# Augmented:  hey CADOCS i wanna to know more about communit smells
# Original:  What kind of community smells can help you detect?
# Augmented:  Whath kind of community smells can help you detect?
# Original:  I wanna to know more about community smells, it seems interesting
# Augmented:  I wanna to know more about community smells, ity seems interesting
# Original:  hey CADOCS, can you please show me some informations about community smells that you can detect?
# Augmented:  hey CADOCS, can you please show me somer informations about community smells that you can detect?
# Original:  hey CADOCS, can you show me some informations about community smells so that you can detect?
# Augmented:  hey CADOCS, can you show me some informations about community smells so that you cav detect?
# Original:  hey CADOCS, can you show me some informations about community smells that only you can detect?
# Augmented:  hey CADOCS, can you show me some informations about community smells tha only you can detect?
# Original:  Could you please tell me more about community smells and which ones you can detect?
# Augmented:  Could en please tell me more about community smells and which ones you can detect?
# Original:  Could you tell me some more about community smells and which ones you can detect?
# Augmented:  Could you tell me some more about comunity smells and which ones you can detect?

# %% [markdown]
# In the end, we print the new dataset. These results will then need to be checked and selected to remove the less realistic and thus less meaningful requests.

# %%
print(dfAug)
# Out:
#                                                request intent
# 0    Hello CADOCS, can you tell me which community ...      0
# 1    Hey CADOCS, tell which community smells are pr...      0
# 2     CADOCS can you tell which community smells ar...      0
# 3    I would like to know what are the community sm...      0
# 4    What are the community smells in the LINK proj...      0
# ..                                                 ...    ...
# 575  hey CADOCS, can you please show me somer infor...      3
# 576  hey CADOCS, can you show me some informations ...      3
# 577  hey CADOCS, can you show me some informations ...      3
# 578  Could en please tell me more about community s...      3
# 579  Could you tell me some more about comunity sme...      3
#
# [580 rows x 2 columns]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# We remove duplicates from the created augmented dataset.

# %%
dfAug = dfAug.loc[dfAug.astype(str).drop_duplicates().index]
print(dfAug)
# Out:
#                                                request intent
# 0    Hello CADOCS, can you tell me which community ...      0
# 1    Hey CADOCS, tell which community smells are pr...      0
# 2     CADOCS can you tell which community smells ar...      0
# 3    I would like to know what are the community sm...      0
# 4    What are the community smells in the LINK proj...      0
# ..                                                 ...    ...
# 575  hey CADOCS, can you please show me somer infor...      3
# 576  hey CADOCS, can you show me some informations ...      3
# 577  hey CADOCS, can you show me some informations ...      3
# 578  Could en please tell me more about community s...      3
# 579  Could you tell me some more about comunity sme...      3
#
# [580 rows x 2 columns]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# We export the dataset in csv format.

# %%
dfAug.to_csv("augmented_dataset.csv", index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()

# %% [markdown]
# In the end, some requests were removed from the new dataset because considered not realistic, but without changing the requests in the original dataset.
